# %%
from opentrons_json import plates,commands
import opentrons_json
import datetime
import uuid
import json

with open('./../protocol-schema.json') as f:
    data = json.load(f)
from jsonschema import validate


with open('/home/koeng/Downloads/response_1554406909932.json') as f:
    test_plate = json.load(f)

opentrons = {'uuid': '43346aba-41e0-483d-ad43-d46a85a6ead5',
             'right_300': '9c3b3205-4fe3-4bf1-af3f-8cf9ab95d918',
             'left_10': '82e95a7a-f335-4178-a7b6-4f38954e497a'
            }

# %%
import string
class Plate():
    def __init__(self, height:int=8, length:int=12,locations:list=[]) -> None:
        positions = []
        for letter in list(string.ascii_uppercase[0:height]):
            for number in range(length):
                positions.append((letter, number+1))
        self.height = height
        self.length = length
        if locations==[]:
            self.locations = [x[0]+str(x[1]) for x in positions]
        else:
            self.locations = locations

    def rows(self)-> list:
        return [list(g) for k, g in groupby(self.locations, key=lambda x: x[0])]
    def columns(self) -> list:
        return [[x for x in self.locations if x[1:] == str(num+1)] for num in range(self.length)]
    def reverse_columns(self)-> list:
        return [sorted(x, reverse=True) for x in self.columns()]
    def flat_columns(self) -> list:
        return [item for sublist in self.columns() for item in sublist]


    def subcolumns(self)-> list:
        if self.height%2 != 0:
            raise StandardError('Not compatible with multichannel')
        spaces = int(self.height/8)
        subcolumns=[]
        for column in self.columns():
            for space in range(spaces):
                count = space
                subcolumn=[]
                while count < len(column):
                    subcolumn.append(column[count])
                    count+=spaces
                subcolumns.append(subcolumn)
        return subcolumns
    
    def use_wells(self,tips:list)-> str:
        self.locations = [v for i, v in enumerate(self.locations) if v not in tips]
        return tips

    def use_number(self,num_wells:int=8,columns=None) -> str:
        if columns == None:
            columns=self.reverse_columns()
        for column in columns:
            if len(column) >= num_wells:
                return self.use_wells(column[0:num_wells])
        raise ValueError("No more tips.")

def data_transfer_comprehension(data_transfer, old_plate=Plate(),new_plate=Plate()):
    output=[]
    for transfer in data_transfer:
        original_index = old_plate.flat_columns().index(transfer[1])
        new_index = new_plate.flat_columns().index(transfer[2])
        for i in range(transfer[0]):
            old_well = old_plate.flat_columns()[i+original_index]
            new_well = new_plate.flat_columns()[i+new_index]
            output.append((old_well,new_well))
    return output
            

def efficient_transfer(derived,full=Plate().subcolumns()):
    derived = Plate(locations=derived).subcolumns()
    transfers=[]
    well = None
    for index,subcolumn in enumerate(derived):
        tip_count = 1
        loc_num=0
        wells=[]
        counter = 0
        for well_index,well in enumerate(subcolumn):

            # Check if this is a new well
            wells.append(well)

            # Check that this is not the last location we can pull from 
            if not well_index+2 > len(subcolumn):
                loc_num = full[index].index(subcolumn[well_index])-well_index-counter



            # If last location, add tips and location, reset new well
            if loc_num != 0:
                if loc_num != 50:
                    transfers.append((len(wells[:-1]),wells[:-1]))
                    wells=[wells[-1]]
                    tip_count=0
                    counter=loc_num
                else:
                    transfers.append((len(wells),wells))
                    wells=[]
                    tip_count=0
                    counter=loc_num
            
            loc_num=50
            tip_count+=1
    return transfers

# %%
def transfer(volume,from_wells,tipbox=Plate(),from_plate_layout=Plate(),to_plate_layout=Plate()):
    def efficient_tip(derived,full):
        transfers=[]
        well = None
        for index,subcolumn in enumerate(derived):
            tip_count = 1
            loc_num=0
            wells=[]
            for well_index,well in enumerate(subcolumn):

                # Check if this is a new well
                wells.append(well)

                # Check that this is not the last location we can pull from 
                if not well_index+2 > len(subcolumn):
                    loc_num = full[index].index(subcolumn[well_index+1])-well_index

                # If last location, add tips and location, reset new well
                if loc_num != 1:
                    transfers.append((tip_count,wells))
                    wells=[]
                    tip_count=0

                loc_num=0
                tip_count+=1
        return transfers
    
    transfers = efficient_tip(Plate(locations=from_wells).subcolumns(),from_plate_layout.subcolumns())
    to = []
    for step in transfers:
        tips = tipbox.use_number(step[0])
        to+=to_plate_layout.use_number(step[0],to_plate_layout.columns())
    transfer_from = [item for sublist in [step[1] for step in transfers] for item in sublist]
    
    individual_transfers = [(volume,) + transfer for transfer in list(zip(transfer_from,to))]
    return transfers,individual_transfers

# %%
class Protocol():
    def __init__(self,robot:dict,labware:dict,procedure:dict,protocol_schema:str='1.0.0',metadata:dict={},defaults:dict={},designer_application:dict={},pipettes:dict={}):
        # Metadata
        self.protocol_schema = protocol_schema
        self.metadata = metadata
        
        # Defaults
        if defaults == {}:
            self.defaults = opentrons_json.default_values
        else:
            self.defaults = defaults
        
        #Designer application
        if designer_application == {}:
            self.designer_application = opentrons_json.designer_application
        else:
            self.designer_application = designer_application
            
        # Pipettes 
        if pipettes == {}:
            self.pipettes = {
                robot['left_10']: opentrons_json.pipette("left", "p10_multi", "p10_multi_v1.3"),
                robot['right_300']: opentrons_json.pipette("right", "p300_multi", "p300_multi_v1.3")
            }
        else:
            self.pipettes = pipettes
        
        self.labware = labware
        self.procedure=procedure
            
    def toJSON(self):
         return {
             "protocol-schema": self.protocol_schema,
             "metadata": self.metadata,
             "default-values": self.defaults,
             "designer-application": self.designer_application,
             "robot": opentrons_json.ot2_standard,
             "pipettes": self.pipettes,
             "labware": self.labware,
             "procedure": self.procedure}
        
def transformation(robot,plate,breadcrumb=None,strain='E.coli Top10',transformant_volume=15,media='lb',transformation_volume=2):
    # Create new plate
    new_plate = {"plate_form": "96pcr",
                 "plate_name": "{}-transformation".format(plate['plate_name']),
                 "plate_type": "transformation",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": str(uuid.uuid4())}

    # Metadata
    metadata = {
            "protocolName": "Transformation of {}".format(plate['uuid']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }

    # Addresses from
    addresses = []
    for well in plate['wells']:
        addresses.append(well['address'])

    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = robot['left_10']
    tips = '11_tip_box'

    labware = {
        tips: opentrons_json.labware('11',"opentrons-tiprack-10ul",name="11_tip_box"),
        'trash_yo': opentrons_json.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentrons_json.labware('5', '96-PCR-flat', name=new_plate['plate_name']),
        plate['uuid']: opentrons_json.labware('4', '96-PCR-flat', name=plate['plate_name'])
    }
    
    # Create new procedure
    procedure = []
    data_transfer = []
    high_level_transfers = efficient_transfer(addresses)
    volume = transformation_volume
    for transfer in high_level_transfers:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(transfer[0])[-1]))
        transfer_from = transfer[1][0]
        procedure.append(commands.aspirate(pipette,volume,plate['uuid'],transfer_from))
        transfer_to = new.use_number(transfer[0],columns=new.columns())[0]
        procedure.append(commands.dispense(pipette,volume,new_plate['uuid'],transfer_to))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))
        data_transfer.append((transfer[0],transfer_from,transfer_to))
    
    protocol = {'uuid': str(uuid.uuid4()),
               'description': metadata['protocolName'],
               'protocol': Protocol(robot,labware,[{'subprocedure': procedure}],metadata=metadata).toJSON(),
               'status': 'planned'}
    
    transfers = data_transfer_comprehension(data_transfer)
    new_wells=[]
    for transfer in transfers:
        old_well = {}
        for well in plate['wells']:
            if well['address'] == transfer[0]:
                old_well = well
        new_well = {'address': transfer[1],
                    'media': media,
                    'organism': strain,
                    'plate_uuid': new_plate['uuid'],
                    'quantity': None,
                    'samples': [sample['uuid'] for sample in old_well['samples']],
                    'volume': transformant_volume+transformation_volume,
                   'well_type': 'transformation'}
        new_wells.append(new_well)
    
    output = {'Plate': [new_plate],
             'Well': new_wells,
             'Protocol': [protocol]}
    return output
    
        

result = transformation(opentrons,test_plate)#['protocol']
#validate(result,schema=data)

# %%
result
# Out:
# {'Plate': [{'plate_form': '96pcr',
#    'plate_name': '23w-transformation',
#    'plate_type': 'transformation',
#    'status': 'planned',
#    'breadcrumb': None,
#    'uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492'}],
#  'Well': [{'address': 'A1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d7f18ce0-b423-463d-9da4-058b2c1a88af'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['f91cdf69-51c5-4e24-85d4-c4ecb64e32ed'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['82521fca-29d1-4e85-97e6-756d2a2991a5'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d222cd88-0d31-49d8-89f0-1156ad7c790c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['e1e016ba-fe6e-4749-969a-6f4c21f74da3'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['547ff662-8219-46c7-8c1d-dc85dbe317b4'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G1',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7b2eb91c-3138-43e9-90b8-fe00233ed053'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['fc780655-673f-4d01-871b-0aca2b931119'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['f91560eb-6c01-4b98-a9df-45575c2a6862'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['9af3dc11-8c4e-4c32-8200-7c1fab6a2955'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['716ddebb-acf7-4768-bad5-c1fef9c71a1c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['facb3d32-d7be-4c37-8296-ec92458e0e54'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['c362bc2f-a576-426a-9649-9b49a149eb4d'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['81b26bbe-bc44-47a7-9c8b-db893a8bf171'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H2',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['cdd63fb1-57cb-4087-a521-3bcffd20128d'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2f0793bc-0478-43d9-90a6-6d85a25a983a'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2f18ed9c-495c-4712-a812-0b345dd6a6e1'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['fbc92258-ecda-4680-b3cd-b4449fabac4c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7fb030fc-12a3-474f-a6eb-187346b2da0f'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['51e63e46-f47a-4cb5-b240-c52ebb0cd7f8'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7b22287d-3478-4640-b9da-3add065f4758'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['342791ec-6254-40d4-9664-2828e5482629'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H3',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['431d2316-fb6b-4f6f-b6d3-af93c96fdc6e'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['78f42966-90de-4d14-aadc-08a4f4978352'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['dd167640-3775-41b7-a7e2-8fb1a529e65e'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['eb93f95a-e4fa-4be0-a30d-0fc9fac22200'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['b843bb6c-f127-45ad-b22e-dadfd07a9dfc'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['14c2451b-c910-4410-9433-0feef0912410'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['9aa93bfb-d7ee-4f05-a222-0094021fb680'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['b2464e56-9ed0-4848-a646-283938fb0be0'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H4',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['1b852dbd-e78b-4ee0-a4bd-9a704c770b21'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d056c79f-dc14-4c2a-a22e-9c59d92ce837'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['cc4b5165-df67-492f-a6fa-4c81483877c1'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['e058989a-d26a-4aea-b494-a305f0d04074'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['f18ec957-6a6f-4380-b12d-46952b9500ac'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['c3ba63b8-4e8b-46b4-97dc-8c67fe9747a6'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['a7151fb8-b098-4c50-ac6f-d7cb3b584acf'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['6e755ef9-e929-4b46-8a3b-26fd0167a1a6'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H5',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['9eb8a477-fe01-4e3c-a649-269d5d8b5cde'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['01a2fddf-4683-46b9-b49f-0e0ad7b6523b'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2af4325f-b610-4714-bcec-b36b919d7660'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7416b0df-2e33-4b81-9216-3b62d7dab8c1'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7a61cb98-edff-43ac-b876-213c6ed5b7f8'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['35addab1-4a5f-4df7-a8a6-0ab844f65d44'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d3fc1e1f-ed72-4cd0-81cc-382456604770'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['0f643d37-293f-46c5-a261-d6b4b9a1c0de'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H6',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['1a2fee17-2b85-4623-a4f6-a6dfb22e4020'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['111fee67-42c5-49c1-9d73-9e7dadc673af'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d0580018-f6c2-4cf4-a872-383a43c0b8b8'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['45a392e5-c018-49db-9f6d-06eafbced552'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['56c1915a-cb20-47d7-8fc0-394dbd172db0'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['c954aadd-68a4-4b64-9dc9-24d7fbb5337b'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['41eda83b-098c-47f2-8368-b1f6d778fd92'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['55a7e15e-12de-4253-9f18-f5cdb84a15eb'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H7',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['de3d9669-dbd9-40d3-a5f5-306b865a4ddd'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['a45bc475-8e62-496b-9512-ee86fd65fd61'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['df08f6eb-b048-42ef-8100-64b1b6f5ffc8'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['f704dc32-1d2e-43b8-a8ed-005dc3fb160f'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['6e6891fb-4841-4c4a-95b1-616152c1f2e2'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['fb0847ad-4957-4f27-81fb-619db7ec2466'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7399ecb0-faba-4e89-932a-513c91ac3ca1'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['02fb68eb-081b-423d-8c8f-3b1b29b64093'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H8',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['53d23852-c50c-4a3f-98d4-c287d970b1c6'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2fb73a7a-6628-4226-aa7d-dc1ffaa37b2c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['b3938e91-dfe2-4eaa-986e-03a63cabf270'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['a1bfd136-0273-411f-bd4f-2f60cb63321d'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['abfca609-846b-4cfd-8871-6dcb2dcc526d'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2abe623d-33c2-4fad-b8a3-2f49ea8496a2'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['49e2f3e0-5499-4930-80c4-49a069551dba'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['0c5e1ddb-892e-4677-ab4c-d08f250e22d6'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H9',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['e0f82b12-d97c-4145-876a-b6ab54d1a629'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['24122581-9627-4bbc-a2e1-fd47722178b5'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['7c5d4ba3-fb3c-4209-a356-9f7a972f8770'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['69986256-715c-48bf-ba08-cb4bee9c9556'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['e8c84120-93d9-4860-aebb-22b28abd746c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['db24d5d0-f43e-41ee-b6c5-ef35acc56ea3'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['182c696d-4b27-444a-832e-aaa48eda69d8'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['68eda2c7-4af3-4bdf-b32e-5c7f2c96ec7c'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H10',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d20f1ac7-c916-48f8-8dd7-9da8f94941e5'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['d910698f-d914-4b9c-9e42-7c3b3c246651'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['1e2f40e8-dfec-46b1-a4f8-ee7a223a7ba6'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['c90bab3b-ce30-4475-b2c2-8c0b3a74cb95'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['afcf560c-9638-476d-9ac7-df4429f9a025'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['1a092657-b88e-4102-b4a4-7ddbcdef422e'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['6b4228a5-b61f-4ffe-b421-31af76560d31'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['267c1a65-01df-40d7-82f2-4025c2b724b4'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H11',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['2b6d6740-b767-4b87-b308-37293b16bbe3'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'A12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['678cb371-69c9-419f-8a2b-379876353d7f'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'B12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['5d44e055-c4f8-4d73-bb82-97c440b0fb7b'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'C12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['b357bf00-db0c-4a3c-95c8-ac677b5ef571'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'D12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['0bb83462-c2c7-4bfa-ad38-e64571316553'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'E12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['bd16e0a2-eeb1-4e2e-a05a-ebeb0c340278'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'F12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['3469a68c-4e2d-4761-b804-1c027c632451'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'G12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['a71fa73b-c736-4595-8008-4c3d4c78c319'],
#    'volume': 17,
#    'well_type': 'transformation'},
#   {'address': 'H12',
#    'media': 'lb',
#    'organism': 'E.coli Top10',
#    'plate_uuid': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#    'quantity': None,
#    'samples': ['159b7e8e-a79e-43a4-a9a7-46dbeddb9520'],
#    'volume': 17,
#    'well_type': 'transformation'}],
#  'Protocol': [{'uuid': '8e4ae712-8781-4678-865f-332a8242d49f',
#    'description': 'Transformation of a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#    'protocol': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Transformation of a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-04-04 15:23:35.139027'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'82e95a7a-f335-4178-a7b6-4f38954e497a': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p10_multi',
#       'model': 'p10_multi_v1.3'},
#      '9c3b3205-4fe3-4bf1-af3f-8cf9ab95d918': {'type': 'pipette',
#       'mount': 'right',
#       'name': 'p300_multi',
#       'model': 'p300_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-10ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '8f98360e-923e-4e8f-bb31-6846d26d8492': {'slot': '5',
#       'model': '96-PCR-flat',
#       'name': '23w-transformation'},
#      'a364eab8-0c68-46b2-8aca-51b72d2f3cb5': {'slot': '4',
#       'model': '96-PCR-flat',
#       'name': '23w'}},
#     'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'H1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A1'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'B1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'C1'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'B1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A2'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A2'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A3'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A3'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A4'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A4'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A4'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A5'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A5'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A5'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A6'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A6'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A6'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A7'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A7'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': '11_tip_box',
#          'well': 'A12'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
#          'well': 'A12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'volume': 2,
#          'labware': '8f98360e-923e-4e8f-bb31-6846d26d8492',
#          'well': 'A12'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '82e95a7a-f335-4178-a7b6-4f38954e497a',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]},
#    'status': 'planned'}]}

# %%
def new_wells_samples(old_plate,data_transfer,new_plate,strain,transformant_volume,transformation_volume,media):
    transfers = data_transfer_comprehension(data_transfer)
    for transfer in transfers:
        old_well = {}
        for well in old_plate['wells']:
            if well['address'] == transfer[0]:
                old_well = well
        new_well = {'address': transfer[1],
                    'media': media,
                    'organism': strain,
                    'plate_uuid': 'a364eab8-0c68-46b2-8aca-51b72d2f3cb5',
                    'quantity': None,
                    'samples': [sample['uuid'] for sample in old_well['samples']],
                    'volume': transformant_volume+transformation_volume,
                   'well_type': 'transformation'},



data_transfer_comprehension(result)
# Out:
# [('A1', 'A1'),
#  ('C1', 'B1'),
#  ('D1', 'C1'),
#  ('E1', 'D1'),
#  ('F1', 'E1'),
#  ('G1', 'F1'),
#  ('H1', 'G1'),
#  ('A2', 'A2'),
#  ('B2', 'B2'),
#  ('C2', 'C2'),
#  ('D2', 'D2'),
#  ('E2', 'E2'),
#  ('F2', 'F2'),
#  ('G2', 'G2'),
#  ('H2', 'H2'),
#  ('A3', 'A3'),
#  ('B3', 'B3'),
#  ('C3', 'C3'),
#  ('D3', 'D3'),
#  ('E3', 'E3'),
#  ('F3', 'F3'),
#  ('G3', 'G3'),
#  ('H3', 'H3'),
#  ('A4', 'A4'),
#  ('B4', 'B4'),
#  ('C4', 'C4'),
#  ('D4', 'D4'),
#  ('E4', 'E4'),
#  ('F4', 'F4'),
#  ('G4', 'G4'),
#  ('H4', 'H4'),
#  ('A5', 'A5'),
#  ('B5', 'B5'),
#  ('C5', 'C5'),
#  ('D5', 'D5'),
#  ('E5', 'E5'),
#  ('F5', 'F5'),
#  ('G5', 'G5'),
#  ('H5', 'H5'),
#  ('A6', 'A6'),
#  ('B6', 'B6'),
#  ('C6', 'C6'),
#  ('D6', 'D6'),
#  ('E6', 'E6'),
#  ('F6', 'F6'),
#  ('G6', 'G6'),
#  ('H6', 'H6'),
#  ('A7', 'A7'),
#  ('B7', 'B7'),
#  ('C7', 'C7'),
#  ('D7', 'D7'),
#  ('E7', 'E7'),
#  ('F7', 'F7'),
#  ('G7', 'G7'),
#  ('H7', 'H7'),
#  ('A8', 'A8'),
#  ('B8', 'B8'),
#  ('C8', 'C8'),
#  ('D8', 'D8'),
#  ('E8', 'E8'),
#  ('F8', 'F8'),
#  ('G8', 'G8'),
#  ('H8', 'H8'),
#  ('A9', 'A9'),
#  ('B9', 'B9'),
#  ('C9', 'C9'),
#  ('D9', 'D9'),
#  ('E9', 'E9'),
#  ('F9', 'F9'),
#  ('G9', 'G9'),
#  ('H9', 'H9'),
#  ('A10', 'A10'),
#  ('B10', 'B10'),
#  ('C10', 'C10'),
#  ('D10', 'D10'),
#  ('E10', 'E10'),
#  ('F10', 'F10'),
#  ('G10', 'G10'),
#  ('H10', 'H10'),
#  ('A11', 'A11'),
#  ('B11', 'B11'),
#  ('C11', 'C11'),
#  ('D11', 'D11'),
#  ('E11', 'E11'),
#  ('F11', 'F11'),
#  ('G11', 'G11'),
#  ('H11', 'H11'),
#  ('A12', 'A12'),
#  ('B12', 'B12'),
#  ('C12', 'C12'),
#  ('D12', 'D12'),
#  ('E12', 'E12'),
#  ('F12', 'F12'),
#  ('G12', 'G12'),
#  ('H12', 'H12')]
