# %%
from opentronsjson import plates,commands
import opentronsjson
import datetime
import uuid
import json
import itertools
from operator import itemgetter
with open('./../protocol-schema.json') as f:
    data = json.load(f)
from jsonschema import validate


with open('/home/koeng/Downloads/response_1554406909932.json') as f:
    test_plate = json.load(f)

opentrons = {'uuid': '43346aba-41e0-483d-ad43-d46a85a6ead5',
             'right_300': '9c3b3205-4fe3-4bf1-af3f-8cf9ab95d918',
             'left_10': '82e95a7a-f335-4178-a7b6-4f38954e497a'
            }
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
import string
class Plate():
    def __init__(self, height:int=8, length:int=12,locations:list=[]) -> None:
        positions = []
        for letter in list(string.ascii_uppercase[0:height]):
            for number in range(length):
                positions.append((letter, number+1))
        self.height = height
        self.length = length
        if locations==[]:
            self.locations = [x[0]+str(x[1]) for x in positions]
        else:
            self.locations = locations

    def rows(self)-> list:
        #tuples good strings bad
        return [list(g) for k, g in groupby(self.locations, key=lambda x: x[0])]
    def columns(self) -> list:
        # why not the same above, sed 's/x[0]/x[1:]'
        return [[x for x in self.locations if x[1:] == str(num+1)] for num in range(self.length)]
    def reverse_columns(self)-> list:
        return [sorted(x, reverse=True) for x in self.columns()]
    def flat_columns(self) -> list:
        # use a classmethod constructor
        # expose only public locations, wells (dict of dict of well), rows, columns
        return [item for sublist in self.columns() for item in sublist]


    def subcolumns(self)-> list:
        if self.height%2 != 0:
            raise StandardError('Not compatible with multichannel')
        spaces = int(self.height/8)
        subcolumns=[]
        for column in self.columns():
            for space in range(spaces):
                count = space
                subcolumn=[]
                while count < len(column):
                    subcolumn.append(column[count])
                    count+=spaces
                subcolumns.append(subcolumn)
        return subcolumns
    
    def use_wells(self,tips:list)-> str:
        self.locations = [v for i, v in enumerate(self.locations) if v not in tips]
        return tips

    def use_number(self,num_wells:int=8,columns=None) -> str:
        if columns == None:
            columns=self.reverse_columns()
        for column in columns:
            if len(column) >= num_wells:
                return self.use_wells(column[0:num_wells])
        raise ValueError("No more tips.")

    def derived_subcolumns(self,loc:list):
        return [[well if well in loc else None for well in col] for col in self.subcolumns()]

        
def data_transfer_comprehension(data_transfer, old_plate=Plate(),new_plate=Plate()):
    output=[]
    for transfer in data_transfer:
        original_index = old_plate.flat_columns().index(transfer[1])
        new_index = new_plate.flat_columns().index(transfer[2])
        for i in range(transfer[0]):
            old_well = old_plate.flat_columns()[i+original_index]
            new_well = new_plate.flat_columns()[i+new_index]
            output.append((old_well,new_well))
    return output
            

def efficient_transfer(derived:list,full=Plate().subcolumns()):
    derived = Plate(locations=derived).subcolumns()
    transfers=[]
    well = None
    for index,subcolumn in enumerate(derived):
        tip_count = 1
        loc_num=0
        wells=[]
        counter = 0
        for well_index,well in enumerate(subcolumn):

            # Check if this is a new well
            wells.append(well)

            # Check that this is not the last location we can pull from 
            if not well_index+2 > len(subcolumn):
                loc_num = full[index].index(subcolumn[well_index])-well_index-counter



            # If last location, add tips and location, reset new well
            if loc_num != 0:
                if loc_num != 50:
                    transfers.append((len(wells[:-1]),wells[:-1]))
                    wells=[wells[-1]]
                    tip_count=0
                    counter=loc_num
                else:
                    transfers.append((len(wells),wells))
                    wells=[]
                    tip_count=0
                    counter=loc_num
            
            loc_num=50
            tip_count+=1
    return transfers

# %%
def transfer(volume,from_wells,tipbox=Plate(),from_plate_layout=Plate(),to_plate_layout=Plate()):
    def efficient_tip(derived,full):
        transfers=[]
        well = None
        for index,subcolumn in enumerate(derived):
            tip_count = 1
            loc_num=0
            wells=[]
            for well_index,well in enumerate(subcolumn):

                # Check if this is a new well
                wells.append(well)

                # Check that this is not the last location we can pull from 
                if not well_index+2 > len(subcolumn):
                    loc_num = full[index].index(subcolumn[well_index+1])-well_index

                # If last location, add tips and location, reset new well
                if loc_num != 1:
                    transfers.append((tip_count,wells))
                    wells=[]
                    tip_count=0

                loc_num=0
                tip_count+=1
        return transfers
    
    transfers = efficient_tip(Plate(locations=from_wells).subcolumns(),from_plate_layout.subcolumns())
    to = []
    for step in transfers:
        tips = tipbox.use_number(step[0])
        to+=to_plate_layout.use_number(step[0],to_plate_layout.columns())
    transfer_from = [item for sublist in [step[1] for step in transfers] for item in sublist]
    
    individual_transfers = [(volume,) + transfer for transfer in list(zip(transfer_from,to))]
    return transfers,individual_transfers

# %%
class Protocol():
    def __init__(self,robot:dict,labware:dict,procedure:dict,protocol_schema:str='1.0.0',metadata:dict={},defaults:dict={},designer_application:dict={},pipettes:dict={}):
        # Metadata
        self.protocol_schema = protocol_schema
        self.metadata = metadata
        
        # Defaults
        if defaults == {}:
            self.defaults = opentronsjson.default_values
        else:
            self.defaults = defaults
        
        #Designer application
        if designer_application == {}:
            self.designer_application = opentronsjson.designer_application
        else:
            self.designer_application = designer_application
            
        # Pipettes 
        if pipettes == {}:
            self.pipettes = {
                robot['left_10']: opentronsjson.pipette("left", "p10_multi", "p10_multi_v1.3"),
                robot['right_300']: opentronsjson.pipette("right", "p300_multi", "p300_multi_v1.3")
            }
        else:
            self.pipettes = pipettes
        
        self.labware = labware
        self.procedure=procedure
            
    def toJSON(self):
         return {
             "protocol-schema": self.protocol_schema,
             "metadata": self.metadata,
             "default-values": self.defaults,
             "designer-application": self.designer_application,
             "robot": opentronsjson.ot2_standard,
             "pipettes": self.pipettes,
             "labware": self.labware,
             "procedure": self.procedure}
        
def plate_merge(robot,plate,breadcrumb=None,strain='E.coli Top10',transformant_volume=15,media='lb',transformation_volume=2):
    # Create new plate
    new_plate = {"plate_form": "96pcr",
                 "plate_name": "{}-transformation".format(plate['plate_name']),
                 "plate_type": "transformation",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": str(uuid.uuid4())}

    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(plate['uuid']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }

    # Addresses from
    addresses = []
    for well in plate['wells']:
        addresses.append(well['address'])

    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = robot['left_10']
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-10ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('5', '96-PCR-flat', name=new_plate['plate_name']),
        plate['uuid']: opentronsjson.labware('4', '96-PCR-flat', name=plate['plate_name'])
    }
    
    # Create new procedure
    procedure = []
    data_transfer = []
    high_level_transfers = efficient_transfer(addresses)
    volume = transformation_volume
    for transfer in high_level_transfers:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(transfer[0])[-1]))
        transfer_from = transfer[1][0]
        procedure.append(commands.aspirate(pipette,volume,plate['uuid'],transfer_from))
        transfer_to = new.use_number(transfer[0],columns=new.columns())[0]
        procedure.append(commands.dispense(pipette,volume,new_plate['uuid'],transfer_to))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))
        data_transfer.append((transfer[0],transfer_from,transfer_to))
    
    protocol = {'uuid': str(uuid.uuid4()),
               'description': metadata['protocolName'],
               'protocol': Protocol(robot,labware,[{'subprocedure': procedure}],metadata=metadata).toJSON(),
               'status': 'planned'}
    
    transfers = data_transfer_comprehension(data_transfer)
    new_wells=[]
    for transfer in transfers:
        old_well = {}
        for well in plate['wells']:
            if well['address'] == transfer[0]:
                old_well = well
        new_well = {'address': transfer[1],
                    'media': media,
                    'organism': strain,
                    'plate_uuid': new_plate['uuid'],
                    'quantity': None,
                    'samples': [sample['uuid'] for sample in old_well['samples']],
                    'volume': transformant_volume+transformation_volume,
                   'well_type': 'transformation'}
        new_wells.append(new_well)
    
    output = {'Plate': [new_plate],
             'Well': new_wells,
             'Protocol': [protocol]}
    return output
    
        

result = transformation(opentrons,test_plate)#['protocol']
#validate(result,schema=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-122c5c754c54> in <module>
#     119
#     120
# --> 121 result = transformation(opentrons,test_plate)#['protocol']
#     122 #validate(result,schema=data)
#
# NameError: name 'transformation' is not defined

# %%
import requests
r = requests.get('https://api.freegenes.org/plates/recurse/dcf981a7-683c-4bad-acfe-8ed35217ec36').json()

# %%
def plates_join_parts(parts:list,plates:list,status='Confirmed'): 
    """Can merge maximum 6 plates into 1. Parts are expressed as UUIDs. Plates are plate recursions """
    used_parts = []
    plate_dict = {}
    # for plate in plates
    #     for part in parts:
    #          if part in plate"
    #              used
    for plate in plates:
        target_wells = []
        for well in plate['wells']:
            for sample in well['samples']:
                part_uuid = sample['part']['uuid']
                if part_uuid in parts and part_uuid not in used_parts:
                    #if sample['status'] == 'Confirmed':
                    if sample['status'] == status:
                        target_wells.append(well['address'])
                        used_parts.append(part_uuid)
        plate_dict[plate['uuid']] = target_wells
    return plate_dict

def group_locs(locs,plate=Plate()):
    # this is good with iter
    # sad without
    transfers = []
    for col in plate.derived_subcolumns(locs):
        trans = []
        for i,well in enumerate(col):
            if well != None:
                trans.append(well)

            if i+1 == len(col):
                if trans != []: transfers.append(trans)
            else:
                if col[i+1] == None:
                    if trans != []: transfers.append(trans)
                    trans = []
    return transfers

def high_level_transfer(parts:list,plates:list,status='Confirmed'):
    plate_dict = plates_join_parts(parts,plates,status)
    return {k: group_locs(v) for k,v in plate_dict.items()}

def plate_merge(name:str,plate_uuid:str,plate_num:int,plate_dict:dict,robot:dict,breadcrumb:None):
    new_plate = {"plate_form": "deep96",
                 "plate_name": "{}-distro-{}".format(name,str(plate_num)),
                 "plate_type": "culture",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": plate_uuid}
    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(new_plate['plate_name']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }


    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = str(uuid.uuid4())
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-300ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('10', '96-deep-well', name=new_plate['plate_name']),
    }
    for i,k in enumerate(list(set([d['from'] for d in plate_dict]))):
        labware[k] = opentronsjson.labware(str(i+4), '96-flat', name=k)
    

    procedure = []
    vol=7
    
    to_wells = []
    from_wells = []
    for d in plate_dict:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(len(d['trans']))[-1]))
        procedure.append(commands.aspirate(pipette,vol,d['from'],d['trans'][0]))
        from_wells.append((d['from'],d['trans']))
        to_wells.append((d['to'],new.use_number(len(d['trans']),columns=new.subcolumns())))
        procedure.append(commands.dispense(pipette,vol,d['to'], to_wells[-1][1][-1]))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))

        
    protocol = Protocol({},labware,[{'subprocedure': procedure}],metadata=metadata,pipettes={pipette:opentronsjson.pipette("left", "p50_multi", "p50_multi_v1.3")}).toJSON()
    return {'protocol': protocol,
    'transfer': list(zip(from_wells,to_wells)), 'plates': {'post': new_plate}}
###
def find_dict(key,value,lst):
    return next((item for item in lst if item[key] == value), None)

def derive_well(old_plate_recurse,old_well,new_well,plate_uuid,volume=5,media='glycerol_lb',well_type='glycerol_stock',derive_sample=False,new_vol=50):
    well = find_dict('address',old_well,old_plate_recurse['wells'])
    def change_well(old_well, address,volume,media,well_type,plate_uuid,derive_sample):
        def change_sample(sample):
            return {'uuid': str(uuid.uuid4()),
                'part_uuid': sample['part_uuid'],
                   'derived_from': sample['uuid'],
                   'status': sample['status'],
                   'evidence': 'Derived'}
        samples = []
        new_well = {'address': address,
               'media': media,
               'organism': old_well['organism'],
               'volume': new_vol,
               'well_type': well_type,
               'plate_uuid': plate_uuid}
        if derive_sample == False:
            new_well['samples'] = [sample['uuid'] for sample in old_well['samples']]
        elif derive_sample == True:
            samples = [change_sample(sample) for sample in old_well['samples']]
            new_well['samples'] = [sample['uuid'] for sample in samples]
        put_well = {'uuid': old_well['uuid'], 'volume': old_well['volume']-volume}
        return new_well,samples,put_well
    well,samples,put_well = change_well(well,new_well,volume,media,well_type,plate_uuid,derive_sample)
    return well,samples,put_well


def return_new_plate(old_plates:list,transfers:list,volume:float,media:str,well_type:str,derive_sample:bool,new_vol:float):
    required_plates = [x[0][0] for x in transfers]
    plates = {plate_id: find_dict('uuid',plate_id,old_plates) for plate_id in required_plates}
    
    new_samples = []
    new_wells = []
    put_wells = []
    for transfer in transfers:
        for i,well in enumerate(transfer[0][1]):
            target_plate = plates[transfer[0][0]]
            new_well, new_sample, put_well = derive_well(target_plate,well,transfer[1][1][i],transfer[1][0], volume,media,well_type,derive_sample,new_vol)
            new_samples+=(new_sample)
            new_wells.append(new_well)
            put_wells.append(put_well)
    return {'wells': {'post': new_wells, 'put': put_wells}, 'samples': {'post': new_samples}}
        
###

def compile_parts(collection_name:str,parts:list,plates:list,status='Confirmed'):
    groups = high_level_transfer(parts,plates,status)
    num_parts = sum([sum([len(tran) for tran in v])for k,v in groups.items()])
    plate_num = int(num_parts/96) + 1

    # Gen protocol
    new_plate = str(uuid.uuid4())
    protocol = []
    count = 0
    for k,v in groups.items():
        for trans in v:
            if count+len(trans)>96: 
                print('new')
                new_plate = str(uuid.uuid4())
                count=0
            else:
                protocol.append({'from': k, 'to': new_plate, 'trans':trans})
                count+=len(trans)
    compile_protocol = {key:[x for x in value if key != 'to' ] for key, value in itertools.groupby(sorted(protocol, key=itemgetter('to')), key=itemgetter('to'))}
    compilation = [plate_merge(collection_name,k,i,v,{},None) for i, (k, v) in enumerate(compile_protocol.items())]
    return [{'data': return_new_plate(plates,comp['transfer'],5,'lb','culture',True,1200),'protocol': {'post': comp['protocol']},'plates':comp['plates']} for comp in compilation]
        
                        
compiled = compile_parts('FG_JCVISYN3',['9d0aeaa7-6ed5-4110-9759-4c6a0340acef','9198f7b6-3edd-4f7f-a52d-6c8ef0ac2044','4f425ab9-dc81-4e17-a9f6-52f10fcc000f','cbcfd9ae-7348-4448-9191-9c242e915f23','c8bc192b-557e-45b5-8831-a8292c8b6176'], [r])
compiled
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-a329eac3a2ec> in <module>
#     163
#     164
# --> 165 compiled = compile_parts('FG_JCVISYN3',['9d0aeaa7-6ed5-4110-9759-4c6a0340acef','9198f7b6-3edd-4f7f-a52d-6c8ef0ac2044','4f425ab9-dc81-4e17-a9f6-52f10fcc000f','cbcfd9ae-7348-4448-9191-9c242e915f23','c8bc192b-557e-45b5-8831-a8292c8b6176'], [r])
#     166 compiled
#
# <ipython-input-78-a329eac3a2ec> in compile_parts(collection_name, parts, plates, status)
#     160     compile_protocol = {key:[x for x in value if key != 'to' ] for key, value in itertools.groupby(sorted(protocol, key=itemgetter('to')), key=itemgetter('to'))}
#     161     compilation = [plate_merge(collection_name,k,i,v,{},None) for i, (k, v) in enumerate(compile_protocol.items())]
# --> 162     return [{'data': return_new_plate(plates,comp['transfer'],5,'lb','culture',True,1200),'protocol': {'post': comp['protocol']},'plates':comp['plates']} for comp in compilation]
#     163
#     164
#
# <ipython-input-78-a329eac3a2ec> in <listcomp>(.0)
#     160     compile_protocol = {key:[x for x in value if key != 'to' ] for key, value in itertools.groupby(sorted(protocol, key=itemgetter('to')), key=itemgetter('to'))}
#     161     compilation = [plate_merge(collection_name,k,i,v,{},None) for i, (k, v) in enumerate(compile_protocol.items())]
# --> 162     return [{'data': return_new_plate(plates,comp['transfer'],5,'lb','culture',True,1200),'protocol': {'post': comp['protocol']},'plates':comp['plates']} for comp in compilation]
#     163
#     164
#
# <ipython-input-78-a329eac3a2ec> in return_new_plate(old_plates, transfers, volume, media, well_type, derive_sample, new_vol)
#     132         for i,well in enumerate(transfer[0][1]):
#     133             target_plate = plates[transfer[0][0]]
# --> 134             new_well, new_sample, put_well = derive_well(target_plate,well,transfer[1][1][i],transfer[1][0], volume,media,well_type,derive_sample,new_vol)
#     135             new_samples+=(new_sample)
#     136             new_wells.append(new_well)
#
# <ipython-input-78-a329eac3a2ec> in derive_well(old_plate_recurse, old_well, new_well, plate_uuid, volume, media, well_type, derive_sample, new_vol)
#     118         put_well = {'uuid': old_well['uuid'], 'volume': old_well['volume']-volume}
#     119         return new_well,samples,put_well
# --> 120     well,samples,put_well = change_well(well,new_well,volume,media,well_type,plate_uuid,derive_sample)
#     121     return well,samples,put_well
#     122
#
# <ipython-input-78-a329eac3a2ec> in change_well(old_well, address, volume, media, well_type, plate_uuid, derive_sample)
#     116             samples = [change_sample(sample) for sample in old_well['samples']]
#     117             new_well['samples'] = [sample['uuid'] for sample in samples]
# --> 118         put_well = {'uuid': old_well['uuid'], 'volume': old_well['volume']-volume}
#     119         return new_well,samples,put_well
#     120     well,samples,put_well = change_well(well,new_well,volume,media,well_type,plate_uuid,derive_sample)
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
test = [(('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7']), ('14934f3f-1342-47f1-93d0-1f0e93a8fc20', ['A1']))]
transfer = (('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7']), ('14934f3f-1342-47f1-93d0-1f0e93a8fc20', ['A1']))
transfer[0]
# Out:
# ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7'])

# %%
plates = requests.get('https://api.freegenes.org/plates/').json()
plate_list = []
for plate in plates:
    if plate['plate_name'][-1] != 'a':
        plate_list.append(requests.get('https://api.freegenes.org/plates/recurse/{}'.format(plate['uuid'])).json())
parts = [x['uuid'] for x in requests.get('https://api.freegenes.org/collections/recurse/78c1a296-69ff-4e42-a2a8-9915bc84bd71').json()['parts']]

# %%
compiled = compile_parts('FG_JCVISYN3',parts,plate_list,status='Confirmed')
compiled
# Out:
# new
# new
# [{'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['516dd400-1a0e-42b1-b7fb-4f51aa61dab6']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['6fb4489f-e0ac-4781-8256-a6cc091e5789']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['47d2643e-22c7-4522-9f20-dbe5488a3a9d']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['3bcecde6-ac07-44a8-bfda-eee986a7139e']},
#      {'address': 'E1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['a4eb880f-c633-4b6f-85b7-d9c4079ae669']},
#      {'address': 'F1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['36e4f930-e9c8-43de-b4f5-0b27d6e5feae']},
#      {'address': 'G1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['60d21cbd-218c-4b19-b1d2-0a2a3d4dd01c']},
#      {'address': 'A2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['67832702-0b4a-4805-95ea-061aa1450782']},
#      {'address': 'B2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['1397ef39-c16c-44d5-8458-70f42b78aa71']},
#      {'address': 'H1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['85e10760-5b47-4576-bf4b-c03e4d609c2d']},
#      {'address': 'C2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['a291761f-4103-4700-a6cc-506c1546c88f']},
#      {'address': 'D2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['8ca06ac6-73e0-43a2-ac09-3667f49bc087']},
#      {'address': 'E2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['e4a88a5d-994e-4f75-a4da-60d53c96471f']},
#      {'address': 'F2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['1cca0ca0-fc22-4aa7-b48a-9653bf240b60']},
#      {'address': 'G2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['d07017ee-efe1-4b06-abbf-bddd7c046b36']},
#      {'address': 'H2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['52e9ea77-3811-42fc-a03b-31e2c1e38b2e']},
#      {'address': 'A3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['3263b147-6a01-4ce5-8b5c-5781b961cf03']},
#      {'address': 'B3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['191a770b-fc18-448e-95b1-d161989d42ad']},
#      {'address': 'C3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['60d474c9-1cb3-46c2-956d-d3f1d85a5e53']},
#      {'address': 'D3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['21a2e435-a317-4d8c-8f80-512f644de79f']},
#      {'address': 'E3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['e921af27-55e7-4b70-8a78-80dec8b5fc90']},
#      {'address': 'F3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['9e7680da-0745-4582-b39b-9cb67d378ba5']},
#      {'address': 'G3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['80f3f57f-d60a-488d-9534-00052abdae35']},
#      {'address': 'A4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['24d08488-c1ad-4a60-a3f9-630c90c9c7d5']},
#      {'address': 'B4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['f751e209-5631-4744-b03c-307522aff190']},
#      {'address': 'C4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': ['3aec23d3-4f5a-4be1-b9fe-a39e1cb4b024']},
#      {'address': 'D4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19',
#       'samples': 

#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': 'a4d7feaf-5a3c-4671-832a-0c03fa2d0a09',
#       'part_uuid': '85dabdf2-1ab1-4db6-b134-82492ffa8a5d',
#       'derived_from': '99de9b55-c10c-4b76-9bda-363fe01464fa',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': '154ab607-ff71-4d37-b9d2-0253930d44b9',
#       'part_uuid': 'd29edb4a-2087-400a-8263-a0ae90e7998d',
#       'derived_from': 'a0ac7065-e424-4f6c-93ee-cbd1c16b382d',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': 'f8da461a-33e5-4e63-b209-abf8f0a247fd',
#       'part_uuid': 'e6ded049-8e1d-4ab2-9d9b-f029c5748098',
#       'derived_from': '49a2982c-6e39-42e4-abfa-f5aa39171e81',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': 'caba4538-cbc7-4db3-b4f7-86c0790826ce',
#       'part_uuid': 'f9273698-1ea7-4988-9d58-660c13224d3c',
#       'derived_from': 'bc5e378f-9b01-4104-b4cf-51457c0bb228',
#       'status': 'Confirmed',
#       'evidence': 'Derived'}]}},
#   'protocol': {'post': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-0',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-05-21 15:28:00.914077'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'7a854aaf-41cd-445b-a5df-13d4007eb2ce': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p50_multi',
#       'model': 'p50_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-300ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '1dc0e68f-2b73-4578-8b3e-25a7ffa5bd19': {'slot': '10',
#       'model': '96-deep-well',
#       'name': 'FG_JCVISYN3-distro-0'},
#      'f74a8ac1-69b1-4100-b784-3eafbd8682ab': {'slot': '4',
# ...
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G5'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'F6'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'C6'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'C6'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'D6'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'G6'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'E6'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'B6'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G6'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A5'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'D7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H5'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'G7'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'G7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'B7'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'D7'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'E7'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'E8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'E8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'D8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'B7'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G7'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'B8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'E9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'E9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'D9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A6'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'F10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H6'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A7'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'H10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H7'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'C10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'C11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'F10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'C9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'C12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'F9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'F11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'F12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'C11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'B9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'E2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'G2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'B10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'F3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'G10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'A10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'B2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'H10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': '11_tip_box',
#          'well': 'E11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'D7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'volume': 7,
#          'labware': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561',
#          'well': 'D11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '493c56e0-fa61-4284-afc4-88018ae1129a',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-2',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '5eeb5ec6-f093-4dff-b175-8ab13cd9c561'}}}]

# %%
with open('/home/koeng/Downloads/jcvisyn3_distro_0.json', 'w') as outfile:  
    json.dump(compiled[0], outfile)

# %%
def transfer_wells(from_plate:dict,to_plate:str,from_address:str,to_address:str,from_vol:int,total_to_vol:int):
    obj = {'wells': {'post': [], 'put': []}, 'samples': {'post': [], 'put': []}}
    for well in from_plate['wells']:
        if well['address'] == from_address:
            obj['wells']['put'].append({'uuid': well['uuid'],'volume': well['volume']-from_vol})
            obj['wells']['post'].append({'organism': well['organism'], 'plate_uuid': to_plate, 'media': 'lb', 'volume': total_to_vol, 'well_type': 'culture'})
            obj['samples']['post'].append({''})

# %%
from jsonschema import validate
import json
with open('/home/koeng/notebooks/validation/protocolSchemaV3.json') as json_file:  
    schema = json.load(json_file)

validate(instance=compiled[0], schema=schema)

# %%
compiled
# Out:
# [{'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['cb5dd0d3-0699-41cc-a24c-9b935b24eb3a']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['0d61ee4d-8f0c-420b-9960-11feae237e97']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['bb357a26-a722-48f7-98ea-b2b57e7909ed']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['3b6c698e-bdea-4373-8972-54519411a1ee']},
#      {'address': 'E1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['c27d9d3e-95d1-4cdd-bb6a-1f9bb1269fd0']},
#      {'address': 'F1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['21adfbfb-03fd-49a0-87f1-59c04b59f9bc']},
#      {'address': 'G1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['476e063b-7576-4033-8b60-0042630380f5']},
#      {'address': 'H1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['1a5f879d-9f45-4dc9-b422-ee8c9e69a8b3']},
#      {'address': 'A2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['950f3f64-0703-4c7d-b7c4-b29d17589c9e']},
#      {'address': 'B2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['ea5701de-182e-46e5-8728-1cf547c559f1']},
#      {'address': 'C2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['848df599-c802-4d05-bf07-4eff25707d33']},
#      {'address': 'D2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['2ca7060d-8941-4020-807d-f2fbc45bb2d0']},
#      {'address': 'E2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['7b493e6a-0b76-4f58-8c68-8aba908b16b6']},
#      {'address': 'F2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['4a8a145a-3217-4269-afde-305141a032e2']},
#      {'address': 'G2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['7c936b74-04c7-4ea6-9a36-17a1b418d398']}]},
#    'samples': {'post': [[{'uuid': '4a342968-5a5e-4440-83de-69e845db9801',
#        'part_uuid': '42296bdc-103d-4a02-bedd-35a87e952c15',
#        'derived_from': 'cf182ee5-db67-4494-a742-5a35832a3f20',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '3f75225e-9427-418f-b1bd-b366f529e7a1',
#        'part_uuid': '5f45b890-4f63-4d9f-b455-b4784d870841',
#        'derived_from': '55f2e318-6f41-49c8-adeb-9b5b2ad2ab57',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '8b462b67-8c1b-4b62-80b4-247a44760990',
#        'part_uuid': 'd0f1d2c6-86d8-49f8-bdb0-396603d1be11',
#        'derived_from': 'd9082d0d-3906-464a-b2ad-fe40bc0a60c0',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '24acd19e-8485-47b0-8320-5f66c82837f2',
#        'part_uuid': '11360779-b8f2-4650-9814-41b1b808995c',
#        'derived_from': 'b2111e03-fb31-4b90-a577-eda1e6544261',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '0409c45d-bd7f-426e-bae8-6e737870fcac',
#        'part_uuid': 'e4cbeb7f-e229-47ee-b14f-6dea983b35ba',
#        'derived_from': '062b4164-2021-4061-91f7-64db8d2f30d6',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '5348a628-c323-487a-b911-e49aa9de61c9',
#        'part_uuid': '67c3d81d-90b1-48d6-b930-db02ff7549af',
#        'derived_from': '23ea0f60-9867-4b47-b04a-281f71bc6b77',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'f6f34d8c-615b-4731-a0b2-b5c3b31a35c4',
#        'part_uuid': 'df0a3daf-d671-43bf-b634-726e0c19fd1d',
#        'derived_from': '40d1fa06-a4e7-450b-b1be-41f391e73ca0',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'aaffd3c8-67a4-436d-8ff9-ca28a8f508d5',
#        'part_uuid': 'c1cfa5fa-c21a-4c81-887b-f6856100e8a1',
#        'derived_from': '33a7738b-aa48-4382-bfe6-09d4546fc319',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '0b2a4adc-206e-445b-b25c-17a312a057ac',
#        'part_uuid': '7f9c0ab1-3b97-4d55-b2fe-c127a3f3e175',
#        'derived_from': '1bd75929-12bf-432b-a524-106d65073e22',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'ab39de76-f8f1-4f54-b209-782b12162408',
#        'part_uuid': '8cb12b7e-205b-4c52-8a82-d7e692d492b0',
#        'derived_from': '8a8b57c5-addb-4755-8298-a05ff59b2a73',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'ed4c3fce-39bd-4298-a563-e1a312ac9fff',
#        'part_uuid': '1fe4b2b9-c94e-4181-8d08-f6fd28ef5d47',
#        'derived_from': '821e232d-577d-46bd-97f7-2a3c4ca77d6a',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '73f6114a-1778-4fe2-b55a-903bcdc79bc9',
#        'part_uuid': '593429dc-6c5c-4c91-8c01-d9c7fc659384',
#        'derived_from': 'd2924eae-b644-40b1-bf01-ddb1f18ed1b1',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '6b4b045b-b185-4c14-b225-8cdedee63c4e',
#        'part_uuid': '8bfacdab-2e7f-4f11-8497-fe4cfbd10887',
#        'derived_from': '0835c3e1-e961-429c-8bd4-94512f202eac',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '60a8477d-a809-4e93-90f9-22a9a0988451',
#        'part_uuid': '759bcd5f-191d-439f-91e7-8bd4c3c75e2d',
#        'derived_from': '5d6972ce-e3c5-43cf-8038-5f9368b74e55',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'b950179c-2419-4cbb-bfbf-e2628c01c750',
#        'part_uuid': 'c8393397-d842-40c5-b851-89cd307bf8c6',
#        'derived_from': 'f8d6d85b-947c-4728-b948-d6ab86a84333',
#        'status': None,
#        'evidence': 'Derived'}]]}},
#   'protocol': {'post': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-0',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-05-21 15:23:09.875460'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'96a1cafc-4536-482f-8eb9-8ebedba1f40b': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p50_multi',
#       'model': 'p50_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-300ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '276126e0-1b46-4840-b5cb-e2b1e6a97739': {'slot': '10',
#       'model': '96-deep-well',
#       'name': 'FG_JCVISYN3-distro-0'},
#      'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7': {'slot': '4',
#       'model': '96-flat',
#       'name': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7'}},
#     'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'H1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'F8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'A1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'G1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'H8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'B1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'F1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'B9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'C1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'B1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'D9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'G1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'A1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'F10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'H1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'H2'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'H10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'A2'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'B2'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'A11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'G2'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-0',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739'}}},
#  {'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['9ed60323-c555-46a6-8fe0-5ac77ca60e62']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['92b51087-a215-4e8e-affd-43314ed7a92f']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['db63e835-6bff-4083-8b86-6c24200bee05']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['336dc562-8109-4a2b-8c4f-fd136dd1f565']},
#      {'address': 'E1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['78a28ab0-1c0e-4410-b598-4d2798d6e976']},
#      {'address': 'F1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['26f1805a-2d3d-45f5-b592-9e85e54a9918']},
#      {'address': 'G1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['170e83b3-b8a8-4493-9a95-34b66d8215fb']},
#      {'address': 'A2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['731750d5-93b4-4277-afa2-c70926183caf']},
#      {'address': 'B2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['61072769-f690-4c02-b02d-2e9018f62836']},
#      {'address': 'C2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['32bd8026-dc07-455d-854b-5a25b486921f']},
#      {'address': 'D2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['fb1f7b1c-0bf8-4305-bdd2-5a6f5adde93e']},
#      {'address': 'H1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['10b216f0-3fa1-4c3a-ad63-ce7c72623980']},
#      {'address': 'E2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['bd6ed2ab-ac81-4d3b-95e9-0468997bc4b6']},
#      {'address': 'F2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['f5f9f712-57f6-4bec-a11c-d66eda3d3235']},
#      {'address': 'G2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['844bae89-cc59-423a-81f4-dd108a0e99ff']},
#      {'address': 'H2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['b9f9c943-9e94-41d1-b28c-f7b4e5f61637']},
#      {'address': 'A3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['79ff001e-a954-4ced-827a-372e615fd619']},
#      {'address': 'B3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['d8564aaa-3f25-4ebe-9429-ad8a801d250c']},
#      {'address': 'C3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['e07c8e3e-cc1f-48fc-a0a2-4cd24efaf492']},
#      {'address': 'D3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['c2d59f1c-f31b-4790-9591-acac9bea7adc']},
#      {'address': 'E3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['6aebf97a-a559-449e-9914-5f71d9d5dd06']},
#      {'address': 'F3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['2e7e3a11-d386-4d66-af6d-b9584e09c71d']},
#      {'address': 'G3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['503139e6-67b0-4cd1-b376-162d68a04e96']},
#      {'address': 'H3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['9d155272-0fb3-44e5-bbec-001c67670112']},
#      {'address': 'A4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['8ab22fdd-9755-42fd-9234-2e85dc38dcb3']},
#      {'address': 'B4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['c012a7dc-6b59-41af-91f7-0b375f8eca49']},
#      {'address': 'C4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['cd49533d-3812-4a8c-b7e1-57e520970578']},
#      {'address': 'D4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['9b198b90-265e-405b-988c-f7633e18aa4f']},
#      {'address': 'E4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['359e3a88-5902-40ce-b889-fa40fdf4223d']},
#      {'address': 'F4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['723afc4c-95c3-411d-8889-ddc2b6ad7fac']},
#      {'address': 'G4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['9532d311-5081-4a72-a643-4126fa97b292']},
#      {'address': 'H4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': 
',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['d30c1e7f-0b6b-4647-96c6-84511ded50c2']},
#      {'address': 'G9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['3668d84a-7bcc-4d21-8adc-6757630ae18d']},
#      {'address': 'H9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['f4fbedd9-068d-4173-bbfe-3f145f87ea59']},
#      {'address': 'A10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['6beca37d-ff3f-47d8-915c-f3997e50be2d']},
#      {'address': 'B10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['5e6af2b6-b2c9-4307-be9f-8e2efa995485']},
#      {'address': 'C10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['aaa99fca-348c-4ecc-88c7-fb6cb3856376']},
#      {'address': 'D10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['dbc33cf3-6427-4a46-b6ad-b00826a8a2da']},
#      {'address': 'E10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['d256b2f4-42f8-4362-b39f-64518e9bce44']},
#      {'address': 'F10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['3ef9b539-be70-4a08-ac20-5cca473e75fd']},
#      {'address': 'G10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['7c13ba3e-bba3-49c0-9944-3c39ad987b3d']},
#      {'address': 'A11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['859f096a-f4ff-4643-b57f-6104ade8191a']},
#      {'address': 'B11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['cae86509-fe13-4468-8426-03350fbc776a']},
#      {'address': 'C11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['77185dcc-9208-45fc-bdbf-afedc16e9a7c']},
#      {'address': 'D11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['582709d2-9261-487b-b667-4e94a743f52d']},
#      {'address': 'E11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['da0f50a7-7270-415f-8e1a-f4c87b6ccf1b']},
#      {'address': 'F11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['a9a29c03-2d59-4da5-8a0d-9c18e2fe27bb']},
#      {'address': 'G11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['28156e95-1c90-4de7-95c8-f12454f600e2']},
#      {'address': 'H10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['fd5fa127-ab0f-4bae-ac8a-d561c6166478']},
#      {'address': 'H11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['065c840e-f675-405e-81af-b72c426906b5']},
#      {'address': 'A12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['3a5aebfc-9dd0-4df9-9998-77317cbf751a']},
#      {'address': 'B12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['617f6156-2b3b-49e2-b99c-56746afb901c']},
#      {'address': 'C12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['5f77c54f-6d56-4df0-a02a-5d193ef5a5d0']},
#      {'address': 'D12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['8dc46fbe-a427-4d3d-a74f-a30790ab6bea']},
#      {'address': 'E12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['aed8f8cf-6f40-41bf-bbf4-6b3a24f825bf']},
#      {'address': 'F12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['f23ffa48-c319-4dab-a040-6fd94f4dbb59']},
#      {'address': 'G12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['f2afee1b-4e10-46cd-bebf-6655cfcb53ef']},
#      {'address': 'H12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['464da65f-32ca-4bcf-9e89-714d339a2c5e']}]},
#    'samples': {'post': [[{'uuid': '8f7c75d6-dc65-4dfd-b4aa-bce3dc6fdab1',
#        'part_uuid': '94d3ed7d-6142-45d1-b95f-e001f230cead',
#        'derived_from': 'ce7790d5-416e-4e09-9775-4f7a36d4959d',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '7a80aa1e-d665-4c5e-aa47-09dd1c60ccfe',
#        'part_uuid': 'cbd16e36-b34b-4d39-9b50-93bd6f9d32e6',
#        'derived_from': '24371b6d-6c65-481d-8b95-e2b7b1aae5d0',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'b9046bc8-bd53-4607-a27b-c1ab4e88e9c0',
#        'part_uuid': '524202cf-e4a2-490d-891d-262ef51606c7',
#        'derived_from': 'a780be69-f24e-4718-a757-2e3c320a1891',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '2d6187c0-6a3d-4594-a0bf-1e0994754860',
#        'part_uuid': 'd025b1b4-96fc-4876-bc93-f1682ed29cc1',
#        'derived_from': 'cd288555-16bf-409b-a498-ed6dce2bff79',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'f3da71c1-c2f5-4d58-8047-3fb1dc617a39',
#        'part_uuid': 'dd8d633b-4d35-4a8a-8470-706422897762',
#        'derived_from': '76d4850d-3736-43ae-9d35-c90a35aa553a',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '5fbb5959-d4ba-4c1d-a0c1-3197b19cc010',
#        'part_uuid': '7c582489-5b16-4321-a749-60fe9127e261',
#        'derived_from': '3cca6a67-53b9-493c-9724-e02108527167',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'd1d9e2be-f10b-4db6-9054-86902e9b5c60',
#        'part_uuid': '4e0da0ab-83ef-4722-a9d3-8d80b531ee3a',
#        'derived_from': 'd20ee732-b42d-4dc6-89a3-11ddda9950e2',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'bacafbf0-0c6c-4774-bf72-aef1ab54ca26',
#        'part_uuid': 'b9a5e34d-f635-49de-a800-92cba9a35369',
#        'derived_from': 'de386ec5-4a7b-4971-ad89-939107da5b36',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '90417c86-cb85-4ad0-aea1-bc0f6faa8fa9',
#        'part_uuid': 'b00cf512-d26e-48e2-a839-cd5eaf77ebbd',
#        'derived_from': '90c5e9ee-5a01-478c-b758-1d3b165fcdf4',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '80314afb-87c8-4061-ace5-00a08a98c7b2',
#        'part_uuid': '56359178-9b01-47cb-b0c3-43f923b7fce4',
#        'derived_from': '35f99982-c8a5-465d-abb9-85470d8c89cc',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'eed4b3b9-1a0f-49ed-ab7d-4c8400630121',
#        'part_uuid': 'f4df5115-a4f7-4290-8c35-9cfa90a56ebe',
#        'derived_from': 'f5edc66f-277b-4f3b-bb36-98c393fd7574',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '30b8156d-b251-4671-bf8f-b4707cfb1d3d',
#        'part_uuid': 'ecabfb4e-b7a0-419f-bc36-941a149074d0',
#        'derived_from': 'd3fb3eac-1dfd-4c87-af9f-343b641d941f',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'a87bfe6f-87ec-40ea-9a50-eb1267ec595a',
#        'part_uuid': '45834e19-4c6d-4062-9e64-149433e19c0e',
#        'derived_from': '5c34322c-5974-4b89-8447-1753ca2be2b1',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '56898d01-1bb3-493b-a013-65362abfa9a9',
#        'part_uuid': 'ccbc92be-fea3-42b1-ba8a-63e5b12692ef',
#        'derived_from': '1794d861-f01c-425a-9c67-d4018ef36d90',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '81aa899d-bba7-4e33-836d-1becd6f86e69',
#        'part_uuid': '1250d01c-da24-4448-91b1-cff46a587be6',
#        'derived_from': 'c01284a1-2de7-4feb-bb88-45d91167b5be',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'ca04095d-9aaf-44d7-b9f0-245498ac8929',
#        'part_uuid': '32979a33-fc88-47cf-815b-a0c9bc4b87b4',
#        'derived_from': '9cbc17ae-e73a-45e1-ab70-1497785e16b2',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'b635fb50-28fb-4469-bce1-4e20d2e9daec',
#        'part_uuid': 'b02ecfa4-cde5-4bcd-9975-1cbe70def969',
#        'derived_from': 'bc77adb9-a4b4-4d2d-8e7d-32feff5c89a6',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '0fd40d82-46ed-490e-9813-8c16f590256a',
#        'part_uuid': 'b42d994f-f450-40d7-b5f0-ab09bf03e235',
#        'derived_from': '3e1f7f84-4fe2-42a8-91db-e001687b00bb',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid':

#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '0cf018a8-77f0-4e10-836c-47c08618c81b',
#        'part_uuid': '7f940f6a-6a21-4e14-9e86-fc74f10cfda7',
#        'derived_from': '906a8504-13aa-4193-af10-264335167af0',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '7ffcfa66-02fb-46dd-9fd5-ab28b8e84776',
#        'part_uuid': 'bc4ab30e-9e6e-48b5-b39e-1a0e5c68d160',
#        'derived_from': '487e6a89-5075-4b81-9a13-f706e478d29f',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '3fda7b09-55a7-4451-88b9-abb6bb87c1da',
#        'part_uuid': '4a185259-dbcb-42bd-b307-ce1679edcb35',
#        'derived_from': '0008199e-06c4-4c24-b38f-f77a656b14f5',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'ef35f9ca-2183-4254-9ad9-690ee87552bf',
#        'part_uuid': '39561d5e-fda9-4d77-bde1-a58e7958c86b',
#        'derived_from': '9ca16376-204a-44b5-a030-d565a508c05c',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '9ecf0f42-3bc1-4b88-8835-fbb45ef07c4e',
#        'part_uuid': '110a4de8-312a-4c03-9121-2c666812d322',
#        'derived_from': 'de7e1a55-fd7d-4785-b7fb-77e28368cf22',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'ccbf7f45-d6bb-4913-84e0-441951ac73c5',
#        'part_uuid': '4bc4a5ca-0057-4006-9a6c-2531dc7147d0',
#        'derived_from': '984b248c-63d5-4b26-b716-0e870f5bd079',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'cc7d9eb8-2afb-4089-ad95-9e628c48efa3',
#        'part_uuid': 'd83df258-4f1b-4375-bf6c-48fc7d0fe4e9',
#        'derived_from': '250d61e2-4725-4b0b-9b70-9682ecf0a427',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '64dd1944-73c7-4375-bae1-8435d13c135a',
#        'part_uuid': '68836e6e-b1f9-4641-b42b-b8bb643101c4',
#        'derived_from': '64654d53-c968-484f-8814-025d99a98c72',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '0f5e1429-5ea7-454e-a6df-ee68d92a90db',
#        'part_uuid': '0c4a4a55-94a3-458c-8ae6-dafc1e8a2ef9',
# ...
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'E8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'C8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'D8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'F8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'A8'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'C9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'H8'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'H9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'H9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'A9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'G9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'E10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'B9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'F9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'G10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'C9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'E9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'B11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'D9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'C9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'A12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'F9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'B9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '1f9db7dc-92d9-4201-a5df-f999ac2c2d2f',
#          'well': 'E12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'G9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'A9'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'F2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'H9'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'H10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'H2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'A10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'G10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'A3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'B10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'F10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'D3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'C10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'E10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'G3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'D10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'B10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'A12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'G10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'G11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'E12'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'B11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'A12'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'A1'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'H12'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'A10'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'A2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'H10'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'E11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'C2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'D11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'C11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'G6'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'F11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'B11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'C7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'G11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': '11_tip_box',
#          'well': 'A11'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'E7'}},
#        {'command': 'dispense',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'volume': 7,
#          'labware': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318',
#          'well': 'H11'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '1e13f27e-d44b-4aab-adf2-053ccfb173c0',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-2',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '7dd1bde0-43b6-4264-a9c7-a9d457ab3318'}}}]
