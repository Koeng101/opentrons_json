# %%
import requests
import json

url = 'https://api.freegenes.org/collections/recurse/78c1a296-69ff-4e42-a2a8-9915bc84bd71'
r = requests.get(url).json()

# %%
count = 0
for part in r['parts']:
    if part['vbd'] == None:
        print('No vbd',part['vector'])
        count+=1
    else:
        print(part['vbd'])
# Out:
# {bsai-AATG,sapi-TAA}.[BBF10K_000316].{GCTT-bsai,AGA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# No vbd {bsai-AATG,}.[BBF10K_000149].{GCTT-bsai,CCG-sapi}_{AGAG-aari}.[BBF10K_003241].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000324].{GCTT-bsai,GAG-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000314].{GCTT-bsai,GAA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000184].{GCTT-bsai,GGA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000262].{GCTT-bsai,GAA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000226].{GCTT-bsai,GAT-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000098].{GCTT-bsai,TCT-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000362].{GCTT-bsai,GTA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# {bsai-AATG,sapi-TAA}.[BBF10K_000306].{GCTT-bsai,GGA-sapi}_{AGAG-aari}.[BBF10K_003242].{aari-GTCA}
# ...

# %%
count
# Out:
# 253
