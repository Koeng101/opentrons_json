# %%
from opentronsjson import plates,commands
import opentronsjson
import datetime
import uuid
import json
import itertools
from operator import itemgetter
with open('./../protocol-schema.json') as f:
    data = json.load(f)
from jsonschema import validate


with open('/home/koeng/Downloads/response_1554406909932.json') as f:
    test_plate = json.load(f)

opentrons = {'uuid': '43346aba-41e0-483d-ad43-d46a85a6ead5',
             'right_300': '9c3b3205-4fe3-4bf1-af3f-8cf9ab95d918',
             'left_10': '82e95a7a-f335-4178-a7b6-4f38954e497a'
            }
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
import string
class Plate():
    def __init__(self, height:int=8, length:int=12,locations:list=[]) -> None:
        positions = []
        for letter in list(string.ascii_uppercase[0:height]):
            for number in range(length):
                positions.append((letter, number+1))
        self.height = height
        self.length = length
        if locations==[]:
            self.locations = [x[0]+str(x[1]) for x in positions]
        else:
            self.locations = locations

    def rows(self)-> list:
        #tuples good strings bad
        return [list(g) for k, g in groupby(self.locations, key=lambda x: x[0])]
    def columns(self) -> list:
        # why not the same above, sed 's/x[0]/x[1:]'
        return [[x for x in self.locations if x[1:] == str(num+1)] for num in range(self.length)]
    def reverse_columns(self)-> list:
        return [sorted(x, reverse=True) for x in self.columns()]
    def flat_columns(self) -> list:
        # use a classmethod constructor
        # expose only public locations, wells (dict of dict of well), rows, columns
        return [item for sublist in self.columns() for item in sublist]


    def subcolumns(self)-> list:
        if self.height%2 != 0:
            raise StandardError('Not compatible with multichannel')
        spaces = int(self.height/8)
        subcolumns=[]
        for column in self.columns():
            for space in range(spaces):
                count = space
                subcolumn=[]
                while count < len(column):
                    subcolumn.append(column[count])
                    count+=spaces
                subcolumns.append(subcolumn)
        return subcolumns
    
    def use_wells(self,tips:list)-> str:
        self.locations = [v for i, v in enumerate(self.locations) if v not in tips]
        return tips

    def use_number(self,num_wells:int=8,columns=None) -> str:
        if columns == None:
            columns=self.reverse_columns()
        for column in columns:
            if len(column) >= num_wells:
                return self.use_wells(column[0:num_wells])
        raise ValueError("No more tips.")

    def derived_subcolumns(self,loc:list):
        return [[well if well in loc else None for well in col] for col in self.subcolumns()]

        
def data_transfer_comprehension(data_transfer, old_plate=Plate(),new_plate=Plate()):
    output=[]
    for transfer in data_transfer:
        original_index = old_plate.flat_columns().index(transfer[1])
        new_index = new_plate.flat_columns().index(transfer[2])
        for i in range(transfer[0]):
            old_well = old_plate.flat_columns()[i+original_index]
            new_well = new_plate.flat_columns()[i+new_index]
            output.append((old_well,new_well))
    return output
            

def efficient_transfer(derived:list,full=Plate().subcolumns()):
    derived = Plate(locations=derived).subcolumns()
    transfers=[]
    well = None
    for index,subcolumn in enumerate(derived):
        tip_count = 1
        loc_num=0
        wells=[]
        counter = 0
        for well_index,well in enumerate(subcolumn):

            # Check if this is a new well
            wells.append(well)

            # Check that this is not the last location we can pull from 
            if not well_index+2 > len(subcolumn):
                loc_num = full[index].index(subcolumn[well_index])-well_index-counter



            # If last location, add tips and location, reset new well
            if loc_num != 0:
                if loc_num != 50:
                    transfers.append((len(wells[:-1]),wells[:-1]))
                    wells=[wells[-1]]
                    tip_count=0
                    counter=loc_num
                else:
                    transfers.append((len(wells),wells))
                    wells=[]
                    tip_count=0
                    counter=loc_num
            
            loc_num=50
            tip_count+=1
    return transfers

# %%
def transfer(volume,from_wells,tipbox=Plate(),from_plate_layout=Plate(),to_plate_layout=Plate()):
    def efficient_tip(derived,full):
        transfers=[]
        well = None
        for index,subcolumn in enumerate(derived):
            tip_count = 1
            loc_num=0
            wells=[]
            for well_index,well in enumerate(subcolumn):

                # Check if this is a new well
                wells.append(well)

                # Check that this is not the last location we can pull from 
                if not well_index+2 > len(subcolumn):
                    loc_num = full[index].index(subcolumn[well_index+1])-well_index

                # If last location, add tips and location, reset new well
                if loc_num != 1:
                    transfers.append((tip_count,wells))
                    wells=[]
                    tip_count=0

                loc_num=0
                tip_count+=1
        return transfers
    
    transfers = efficient_tip(Plate(locations=from_wells).subcolumns(),from_plate_layout.subcolumns())
    to = []
    for step in transfers:
        tips = tipbox.use_number(step[0])
        to+=to_plate_layout.use_number(step[0],to_plate_layout.columns())
    transfer_from = [item for sublist in [step[1] for step in transfers] for item in sublist]
    
    individual_transfers = [(volume,) + transfer for transfer in list(zip(transfer_from,to))]
    return transfers,individual_transfers

# %%
class Protocol():
    def __init__(self,robot:dict,labware:dict,procedure:dict,protocol_schema:str='1.0.0',metadata:dict={},defaults:dict={},designer_application:dict={},pipettes:dict={}):
        # Metadata
        self.protocol_schema = protocol_schema
        self.metadata = metadata
        
        # Defaults
        if defaults == {}:
            self.defaults = opentronsjson.default_values
        else:
            self.defaults = defaults
        
        #Designer application
        if designer_application == {}:
            self.designer_application = opentronsjson.designer_application
        else:
            self.designer_application = designer_application
            
        # Pipettes 
        if pipettes == {}:
            self.pipettes = {
                robot['left_10']: opentronsjson.pipette("left", "p10_multi", "p10_multi_v1.3"),
                robot['right_300']: opentronsjson.pipette("right", "p300_multi", "p300_multi_v1.3")
            }
        else:
            self.pipettes = pipettes
        
        self.labware = labware
        self.procedure=procedure
            
    def toJSON(self):
         return {
             "protocol-schema": self.protocol_schema,
             "metadata": self.metadata,
             "default-values": self.defaults,
             "designer-application": self.designer_application,
             "robot": opentronsjson.ot2_standard,
             "pipettes": self.pipettes,
             "labware": self.labware,
             "procedure": self.procedure}
        
def plate_merge(robot,plate,breadcrumb=None,strain='E.coli Top10',transformant_volume=15,media='lb',transformation_volume=2):
    # Create new plate
    new_plate = {"plate_form": "96pcr",
                 "plate_name": "{}-transformation".format(plate['plate_name']),
                 "plate_type": "transformation",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": str(uuid.uuid4())}

    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(plate['uuid']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }

    # Addresses from
    addresses = []
    for well in plate['wells']:
        addresses.append(well['address'])

    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = robot['left_10']
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-10ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('5', '96-PCR-flat', name=new_plate['plate_name']),
        plate['uuid']: opentronsjson.labware('4', '96-PCR-flat', name=plate['plate_name'])
    }
    
    # Create new procedure
    procedure = []
    data_transfer = []
    high_level_transfers = efficient_transfer(addresses)
    volume = transformation_volume
    for transfer in high_level_transfers:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(transfer[0])[-1]))
        transfer_from = transfer[1][0]
        procedure.append(commands.aspirate(pipette,volume,plate['uuid'],transfer_from))
        transfer_to = new.use_number(transfer[0],columns=new.columns())[0]
        procedure.append(commands.dispense(pipette,volume,new_plate['uuid'],transfer_to))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))
        data_transfer.append((transfer[0],transfer_from,transfer_to))
    
    protocol = {'uuid': str(uuid.uuid4()),
               'description': metadata['protocolName'],
               'protocol': Protocol(robot,labware,[{'subprocedure': procedure}],metadata=metadata).toJSON(),
               'status': 'planned'}
    
    transfers = data_transfer_comprehension(data_transfer)
    new_wells=[]
    for transfer in transfers:
        old_well = {}
        for well in plate['wells']:
            if well['address'] == transfer[0]:
                old_well = well
        new_well = {'address': transfer[1],
                    'media': media,
                    'organism': strain,
                    'plate_uuid': new_plate['uuid'],
                    'quantity': None,
                    'samples': [sample['uuid'] for sample in old_well['samples']],
                    'volume': transformant_volume+transformation_volume,
                   'well_type': 'transformation'}
        new_wells.append(new_well)
    
    output = {'Plate': [new_plate],
             'Well': new_wells,
             'Protocol': [protocol]}
    return output
    
        

result = transformation(opentrons,test_plate)#['protocol']
#validate(result,schema=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-122c5c754c54> in <module>
#     119
#     120
# --> 121 result = transformation(opentrons,test_plate)#['protocol']
#     122 #validate(result,schema=data)
#
# NameError: name 'transformation' is not defined

# %%
import requests
r = requests.get('https://api.freegenes.org/plates/recurse/dcf981a7-683c-4bad-acfe-8ed35217ec36').json()

# %%
def plates_join_parts(parts:list,plates:list,status='Confirmed'): 
    """Can merge maximum 6 plates into 1. Parts are expressed as UUIDs. Plates are plate recursions """
    used_parts = []
    plate_dict = {}
    # for plate in plates
    #     for part in parts:
    #          if part in plate"
    #              used
    for plate in plates:
        target_wells = []
        for well in plate['wells']:
            for sample in well['samples']:
                part_uuid = sample['part']['uuid']
                if part_uuid in parts and part_uuid not in used_parts:
                    #if sample['status'] == 'Confirmed':
                    if sample['status'] == status and sample['evidence'] != 'Sanger':
                        target_wells.append(well['address'])
                        used_parts.append(part_uuid)
        plate_dict[plate['uuid']] = target_wells
    print('Processing {} parts'.format(len(used_parts)))
    return plate_dict

def group_locs(locs,plate=Plate()):
    # this is good with iter
    # sad without
    transfers = []
    for col in plate.derived_subcolumns(locs):
        trans = []
        for i,well in enumerate(col):
            if well != None:
                trans.append(well)

            if i+1 == len(col):
                if trans != []: transfers.append(trans)
            else:
                if col[i+1] == None:
                    if trans != []: transfers.append(trans)
                    trans = []
    return transfers

def high_level_transfer(parts:list,plates:list,status='Confirmed'):
    plate_dict = plates_join_parts(parts,plates,status)
    return {k: group_locs(v) for k,v in plate_dict.items()}

def plate_merge(name:str,plate_uuid:str,plate_num:int,plate_dict:dict,robot:dict,breadcrumb:None):
    new_plate = {"plate_form": "deep96",
                 "plate_name": "{}-distro-{}".format(name,str(plate_num)),
                 "plate_type": "culture",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": plate_uuid}
    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(new_plate['plate_name']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }


    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = str(uuid.uuid4())
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-300ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('10', '96-deep-well', name=new_plate['plate_name']),
    }
    for i,k in enumerate(list(set([d['from'] for d in plate_dict]))):
        labware[k] = opentronsjson.labware(str(i+4), '96-flat', name=k)
    

    procedure = []
    vol=7
    
    to_wells = []
    from_wells = []
    for d in plate_dict:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(len(d['trans']))[-1]))
        procedure.append(commands.aspirate(pipette,vol,d['from'],d['trans'][0]))
        from_wells.append((d['from'],d['trans']))
        to_wells.append((d['to'],new.use_number(len(d['trans']),columns=new.subcolumns())))
        procedure.append(commands.dispense(pipette,vol,d['to'], to_wells[-1][1][-1]))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))

        
    protocol = Protocol({},labware,[{'subprocedure': procedure}],metadata=metadata,pipettes={pipette:opentronsjson.pipette("left", "p50_multi", "p50_multi_v1.3")}).toJSON()
    return {'protocol': protocol,
    'transfer': list(zip(from_wells,to_wells)), 'plates': {'post': new_plate}}
###
def find_dict(key,value,lst):
    return next((item for item in lst if item[key] == value), None)

def derive_well(old_plate_recurse,old_well,new_well,plate_uuid,volume=5,media='glycerol_lb',well_type='glycerol_stock',derive_sample=False,new_vol=50):
    well = find_dict('address',old_well,old_plate_recurse['wells'])
    def change_well(old_well, address,volume,media,well_type,plate_uuid,derive_sample):
        def change_sample(sample):
            return {'uuid': str(uuid.uuid4()),
                'part_uuid': sample['part_uuid'],
                   'derived_from': sample['uuid'],
                   'status': sample['status'],
                   'evidence': 'Derived'}
        samples = []
        new_well = {'address': address,
               'media': media,
               'organism': old_well['organism'],
               'volume': new_vol,
               'well_type': well_type,
               'plate_uuid': plate_uuid}
        if derive_sample == False:
            new_well['samples'] = [sample['uuid'] for sample in old_well['samples']]
        elif derive_sample == True:
            samples = [change_sample(sample) for sample in old_well['samples']]
            new_well['samples'] = [sample['uuid'] for sample in samples]
        put_well = {'uuid': old_well['uuid'], 'volume': old_well['volume']-volume}
        return new_well,samples,put_well
    well,samples,put_well = change_well(well,new_well,volume,media,well_type,plate_uuid,derive_sample)
    return well,samples,put_well


def return_new_plate(old_plates:list,transfers:list,volume:float,media:str,well_type:str,derive_sample:bool,new_vol:float):
    required_plates = [x[0][0] for x in transfers]
    plates = {plate_id: find_dict('uuid',plate_id,old_plates) for plate_id in required_plates}
    
    new_samples = []
    new_wells = []
    put_wells = []
    for transfer in transfers:
        for i,well in enumerate(transfer[0][1]):
            target_plate = plates[transfer[0][0]]
            new_well, new_sample, put_well = derive_well(target_plate,well,transfer[1][1][i],transfer[1][0], volume,media,well_type,derive_sample,new_vol)
            new_samples+=(new_sample)
            new_wells.append(new_well)
            put_wells.append(put_well)
    return {'wells': {'post': new_wells, 'put': put_wells}, 'samples': {'post': new_samples}}
        
###

def compile_parts(collection_name:str,parts:list,plates:list,status='Confirmed'):
    groups = high_level_transfer(parts,plates,status)
    num_parts = sum([sum([len(tran) for tran in v])for k,v in groups.items()])
    plate_num = int(num_parts/96) + 1

    # Gen protocol
    new_plate = str(uuid.uuid4())
    protocol = []
    count = 0
    for k,v in groups.items():
        for trans in v:
            if count+len(trans)>96: 
                print('new')
                new_plate = str(uuid.uuid4())
                count=0
            else:
                protocol.append({'from': k, 'to': new_plate, 'trans':trans})
                count+=len(trans)
    compile_protocol = {key:[x for x in value if key != 'to' ] for key, value in itertools.groupby(sorted(protocol, key=itemgetter('to')), key=itemgetter('to'))}
    compilation = [plate_merge(collection_name,k,i,v,{},None) for i, (k, v) in enumerate(compile_protocol.items())]
    return [{'data': return_new_plate(plates,comp['transfer'],5,'lb','culture',True,1200),'protocol': {'post': comp['protocol']},'plates':comp['plates']} for comp in compilation]
        
                        
compiled = compile_parts('FG_JCVISYN3',['9d0aeaa7-6ed5-4110-9759-4c6a0340acef','9198f7b6-3edd-4f7f-a52d-6c8ef0ac2044','4f425ab9-dc81-4e17-a9f6-52f10fcc000f','cbcfd9ae-7348-4448-9191-9c242e915f23','c8bc192b-557e-45b5-8831-a8292c8b6176'], [r])
compiled
# Out:
# Processing 3 parts
# [{'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a',
#       'samples': ['4c080560-94b5-4d7e-b9fc-5ebe4d3dfe1b']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a',
#       'samples': ['33a4e05c-3d7f-4f5c-b5d0-864933969861']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a',
#       'samples': ['f9693d07-9964-4223-868a-5b87f4038dc1']}],
#     'put': [{'uuid': 'aebd23c2-b34c-4473-b5a5-a7a6076eb34f', 'volume': 45.0},
#      {'uuid': 'a2278af8-cd8a-4a6c-b5a4-4aaa4e8542d3', 'volume': 45.0},
#      {'uuid': '7e6a3006-b3c3-4a47-93f3-a250dfa523b1', 'volume': 45.0}]},
#    'samples': {'post': [{'uuid': '4c080560-94b5-4d7e-b9fc-5ebe4d3dfe1b',
#       'part_uuid': '9d0aeaa7-6ed5-4110-9759-4c6a0340acef',
#       'derived_from': '7b03ad1d-5cb7-4b34-b4b2-910bde5a0274',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': '33a4e05c-3d7f-4f5c-b5d0-864933969861',
#       'part_uuid': '9198f7b6-3edd-4f7f-a52d-6c8ef0ac2044',
#       'derived_from': '094fe8b6-c90b-41cf-8eef-fa63d88cb2f3',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': 'f9693d07-9964-4223-868a-5b87f4038dc1',
#       'part_uuid': '4f425ab9-dc81-4e17-a9f6-52f10fcc000f',
#       'derived_from': '1c8c856d-e4fd-4755-aa3c-92f34936f800',
#       'status': 'Confirmed',
#       'evidence': 'Derived'}]}},
#   'protocol': {'post': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-0',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-05-21 17:18:46.781217'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'2cb22c33-72f8-4a40-a74d-82f6475e3471': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p50_multi',
#       'model': 'p50_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-300ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '6aa3bfcd-d6eb-4f0c-8226-912b3599212a': {'slot': '10',
#       'model': '96-deep-well',
#       'name': 'FG_JCVISYN3-distro-0'},
#      'dcf981a7-683c-4bad-acfe-8ed35217ec36': {'slot': '4',
#       'model': '96-flat',
#       'name': 'dcf981a7-683c-4bad-acfe-8ed35217ec36'}},
#     'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'labware': '11_tip_box',
#          'well': 'G1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'volume': 7,
#          'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#          'well': 'B2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'volume': 7,
#          'labware': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a',
#          'well': 'B1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'labware': '11_tip_box',
#          'well': 'F1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'volume': 7,
#          'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#          'well': 'G4'}},
#        {'command': 'dispense',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'volume': 7,
#          'labware': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a',
#          'well': 'C1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '2cb22c33-72f8-4a40-a74d-82f6475e3471',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-0',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '6aa3bfcd-d6eb-4f0c-8226-912b3599212a'}}}]

# %%
test = [(('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7']), ('14934f3f-1342-47f1-93d0-1f0e93a8fc20', ['A1']))]
transfer = (('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7']), ('14934f3f-1342-47f1-93d0-1f0e93a8fc20', ['A1']))
transfer[0]
# Out:
# ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7'])

# %%
plates = requests.get('https://api.freegenes.org/plates/').json()
plate_list = []
for plate in plates:
    if plate['plate_name'][-1] != 'a':
        plate_list.append(requests.get('https://api.freegenes.org/plates/recurse/{}'.format(plate['uuid'])).json())
parts = [x['uuid'] for x in requests.get('https://api.freegenes.org/collections/recurse/78c1a296-69ff-4e42-a2a8-9915bc84bd71').json()['parts']]

# %%
len(parts)
# Out:
# 453

# %%
compiled = compile_parts('FG_JCVISYN3',parts,plate_list,status='Confirmed')
compiled
# Out:
# Processing 198 parts
# new
# new
# [{'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['96399ee8-5500-4e48-8bd4-77be6476c9c2']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['88722c66-d5aa-496c-892f-24bf04fe9b8a']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['e36ea09b-60fb-47c4-9ac7-0757ffc91342']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['a4eedf89-6ec6-40f0-9b51-c5508d159095']},
#      {'address': 'E1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['136c6391-df63-4d12-b1e6-ad47f27d5c16']},
#      {'address': 'F1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['a84ae7e7-7932-4494-b9e5-27c2813e4dae']},
#      {'address': 'G1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['a8232aa5-f902-44ed-b694-dc67d0e09a57']},
#      {'address': 'A2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['2d0dec1c-a57e-45f0-899b-979b891b4dbd']},
#      {'address': 'B2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['7d76e5c0-60c9-4719-9fcd-ea9b339c5b93']},
#      {'address': 'C2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['0dce34d4-4bcc-481f-9f22-ce098e405fc0']},
#      {'address': 'D2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['3c18b1f4-21a0-46a5-93a2-b1d15834924c']},
#      {'address': 'E2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['96954087-798f-4ae9-8df5-b46375229987']},
#      {'address': 'F2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['8c5e6134-3365-4229-ba2d-6d5ee863b3eb']},
#      {'address': 'G2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['817559e9-74da-4c3c-9f07-b39faec0332a']},
#      {'address': 'H2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['b4651cdc-b51f-41f4-b480-19c90ac3faca']},
#      {'address': 'A3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['07612cf8-f8fe-471e-b3b7-59f8e10ed41c']},
#      {'address': 'B3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['8fade992-6425-472f-8a7c-77d216abef60']},
#      {'address': 'C3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['6fe44231-a3e7-457b-8e38-0aa11b5af9ca']},
#      {'address': 'D3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['3fe1d73d-30fc-416b-bce6-16b5782c0821']},
#      {'address': 'E3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['75065235-f9c8-47d8-9f78-120d237f5e06']},
#      {'address': 'F3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['d13c710c-999d-438d-9598-939a6ee5e53f']},
#      {'address': 'G3',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['c527c0ff-d34e-4d20-bb22-2891855cd053']},
#      {'address': 'A4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['7ec5b2fb-e020-4cef-b903-43279a45eed6']},
#      {'address': 'B4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['aa756f91-65cb-4867-99a8-2d40cbaae529']},
#      {'address': 'C4',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': 
',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['51c9a879-d758-4a8d-b647-3e45f6767f0e']},
#      {'address': 'H8',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['7af411b4-f436-47fe-a14f-0e913785d58a']},
#      {'address': 'A9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['c7d20ebc-216f-4a76-ad47-485a011858e2']},
#      {'address': 'B9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['26717bcb-ade9-48a9-830c-799e91aaa6ff']},
#      {'address': 'C9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['a5bd8677-c6f4-48bd-8485-96feda08691c']},
#      {'address': 'D9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['107c52a8-10c9-4542-a31a-c529cdda2d77']},
#      {'address': 'E9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['47ffddc7-7757-4916-9092-36cbdb4b27fc']},
#      {'address': 'F9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['621f70fa-b574-4159-8127-058d07ffa562']},
#      {'address': 'G9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['74f7760f-0032-49db-a47f-96a04267d257']},
#      {'address': 'H9',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['89eb9ed5-0400-4883-b188-01cb3dd6b468']},
#      {'address': 'A10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['6f8e741b-ba73-4467-aca6-d1bbf7380f4d']},
#      {'address': 'B10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['d309056c-286d-4708-ac5d-b969d29167f9']},
#      {'address': 'C10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['cef9827f-a561-4b16-869a-a90cb7cd5af9']},
#      {'address': 'D10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['3f874997-a452-4278-a976-5380b29a2756']},
#      {'address': 'E10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['f3bec33c-29dd-4605-b2fe-2127a3d71061']},
#      {'address': 'F10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['c7d4ef0b-b6ab-4d5f-a79c-6ed9c9cb2ff4']},
#      {'address': 'G10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['0d90858c-0303-425c-aaf4-ce8cf56877c4']},
#      {'address': 'H10',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['c300aa39-3210-467d-8adc-915fd18488ef']},
#      {'address': 'A11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['685a9bb0-107e-4745-b14f-4b311de65850']},
#      {'address': 'B11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['4b869da1-b4f8-41d3-bb98-ab528cf163b3']},
#      {'address': 'C11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['8b2d5d61-b492-4bd7-84fd-e4e1f76db705']},
#      {'address': 'D11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['3b4f3898-8976-40a6-882b-240cc10802c9']},
#      {'address': 'E11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['7f8f378e-dea3-4c16-9f40-4434770f256c']},
#      {'address': 'F11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['23c94f1b-a1bf-48bb-8f85-888c6ba86fef']},
#      {'address': 'G11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['952768d3-19e4-442a-a0f4-6345c2aa614b']},
#      {'address': 'H11',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['522ffca8-109f-40ba-9bf2-a0072479699c']},
#      {'address': 'A12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['ab6a755d-f992-423a-8b82-2be397c1d8d1']},
#      {'address': 'B12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['90b4c9ab-d574-45d1-bb95-e19e3bac126f']},
#      {'address': 'C12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['4e22e93d-a08c-4c51-ad37-ce3ab774834c']},
#      {'address': 'D12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['eeea52f4-8a33-43c6-836e-c261911e9c42']},
#      {'address': 'E12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['9dd1e279-1b16-435a-b2a1-aa266d583070']},
#      {'address': 'F12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['0409cef2-b08d-4080-b76a-692e21ddaaa6']},
#      {'address': 'G12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['0a67ecd5-a32e-4ab8-83f3-765b0a46590f']},
#      {'address': 'H12',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '00b259ea-aa54-4634-983f-d6ab2b00bcef',
#       'samples': ['0ef4fadc-d49f-4318-a440-a56a1d99223a']}],
#     'put': [{'uuid': '31478fc1-0926-4e1b-a2e8-6323bb8a9b95', 'volume': 45.0},
#      {'uuid': 'c92045cb-408f-4e5e-bdc7-c94f23de5dd2', 'volume': 45.0},
#      {'uuid': '05461e84-24f9-445b-88b6-9b36fcfe83fc', 'volume': 45.0},
},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '9d0d48b6-725b-4512-8ff5-0abef9693140',
#       'samples': ['be101dc8-1cf1-410b-9843-2909aa0dea16']}],
#     'put': [{'uuid': 'ebb3721e-fe34-47d6-8aad-4740172445ac', 'volume': 45.0},
#      {'uuid': '9a614e36-f4cf-406c-bc5d-b7eca036932b', 'volume': 45.0}]},
#    'samples': {'post': [{'uuid': 'c4d3a14f-fdd7-4aae-9410-ef85bbb5890c',
#       'part_uuid': '66f8fd3b-4683-4825-b25b-57e2974b7a6c',
#       'derived_from': 'c8daf1ea-4508-4a42-bcca-945e0ee895f3',
#       'status': 'Confirmed',
#       'evidence': 'Derived'},
#      {'uuid': 'be101dc8-1cf1-410b-9843-2909aa0dea16',
#       'part_uuid': '08841e8b-f64b-489e-80d5-3e6260c8c583',
#       'derived_from': '8d9b518e-d6e4-4353-98cd-87bf31bafb33',
#       'status': 'Confirmed',
#       'evidence': 'Derived'}]}},
#   'protocol': {'post': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-2',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-05-21 17:18:50.574707'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'86740476-b08d-4263-93ca-69de73f7b870': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p50_multi',
#       'model': 'p50_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-300ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '9d0d48b6-725b-4512-8ff5-0abef9693140': {'slot': '10',
#       'model': '96-deep-well',
#       'name': 'FG_JCVISYN3-distro-2'},
#      'fcc9165e-bd34-4aa9-8967-6591fbc0d0da': {'slot': '4',
#       'model': '96-flat',
#       'name': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da'},
#      'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7': {'slot': '5',
#       'model': '96-flat',
#       'name': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7'}},
#     'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'labware': '11_tip_box',
#          'well': 'H1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'volume': 7,
#          'labware': 'fcc9165e-bd34-4aa9-8967-6591fbc0d0da',
#          'well': 'F3'}},
#        {'command': 'dispense',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'volume': 7,
#          'labware': '9d0d48b6-725b-4512-8ff5-0abef9693140',
#          'well': 'A1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'labware': '11_tip_box',
#          'well': 'G1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'B2'}},
#        {'command': 'dispense',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'volume': 7,
#          'labware': '9d0d48b6-725b-4512-8ff5-0abef9693140',
#          'well': 'B1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '86740476-b08d-4263-93ca-69de73f7b870',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-2',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '9d0d48b6-725b-4512-8ff5-0abef9693140'}}}]

# %%
with open('/home/koeng/Downloads/build_jcvi.json', 'w') as outfile:  
    json.dump(compiled, outfile)

# %%
from jsonschema import validate
import json
with open('/home/koeng/notebooks/validation/protocolSchemaV3.json') as json_file:  
    schema = json.load(json_file)

validate(instance=compiled[0], schema=schema)

# %%
compiled
# Out:
# [{'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['cb5dd0d3-0699-41cc-a24c-9b935b24eb3a']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['0d61ee4d-8f0c-420b-9960-11feae237e97']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': ['bb357a26-a722-48f7-98ea-b2b57e7909ed']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#       'samples': 
1',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '6b4b045b-b185-4c14-b225-8cdedee63c4e',
#        'part_uuid': '8bfacdab-2e7f-4f11-8497-fe4cfbd10887',
#        'derived_from': '0835c3e1-e961-429c-8bd4-94512f202eac',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': '60a8477d-a809-4e93-90f9-22a9a0988451',
#        'part_uuid': '759bcd5f-191d-439f-91e7-8bd4c3c75e2d',
#        'derived_from': '5d6972ce-e3c5-43cf-8038-5f9368b74e55',
#        'status': None,
#        'evidence': 'Derived'}],
#      [{'uuid': 'b950179c-2419-4cbb-bfbf-e2628c01c750',
#        'part_uuid': 'c8393397-d842-40c5-b851-89cd307bf8c6',
#        'derived_from': 'f8d6d85b-947c-4728-b948-d6ab86a84333',
#        'status': None,
#        'evidence': 'Derived'}]]}},
#   'protocol': {'post': {'protocol-schema': '1.0.0',
#     'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-0',
#      'author': 'Keoni Gandall',
#      'datetime': '2019-05-21 15:23:09.875460'},
#     'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#       'p10_multi': 5,
#       'p50_single': 25,
#       'p50_multi': 25,
#       'p300_single': 150,
#       'p300_multi': 150,
#       'p1000_single': 500},
#      'dispense-flow-rate': {'p10_single': 10,
#       'p10_multi': 10,
#       'p50_single': 50,
#       'p50_multi': 50,
#       'p300_single': 300,
#       'p300_multi': 300,
#       'p1000_single': 1000},
#      'aspirate-mm-from-bottom': 1,
#      'dispense-mm-from-bottom': 0.5,
#      'touch-tip-mm-from-top': -1},
#     'designer-application': {'application-name': 'opentrons_json',
#      'application-version': '1.0.0',
#      'data': {}},
#     'robot': {'model': 'OT-2 Standard'},
#     'pipettes': {'96a1cafc-4536-482f-8eb9-8ebedba1f40b': {'type': 'pipette',
#       'mount': 'left',
#       'name': 'p50_multi',
#       'model': 'p50_multi_v1.3'}},
#     'labware': {'11_tip_box': {'slot': '11',
#       'model': 'opentrons-tiprack-300ul',
#       'name': '11_tip_box'},
#      'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#      '276126e0-1b46-4840-b5cb-e2b1e6a97739': {'slot': '10',
#       'model': '96-deep-well',
#       'name': 'FG_JCVISYN3-distro-0'},
#      'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7': {'slot': '4',
#       'model': '96-flat',
#       'name': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7'}},
#     'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'H1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'F8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'A1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'G1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'H8'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'B1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'F1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'B9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'C1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'B1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'D9'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'G1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'A1'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'F10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'H1'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'H2'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'H10'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'A2'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}},
#        {'command': 'pick-up-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': '11_tip_box',
#          'well': 'B2'}},
#        {'command': 'aspirate',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': 'af2866f7-7a89-45d7-ae5a-0b2c2d0829d7',
#          'well': 'A11'}},
#        {'command': 'dispense',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'volume': 7,
#          'labware': '276126e0-1b46-4840-b5cb-e2b1e6a97739',
#          'well': 'G2'}},
#        {'command': 'drop-tip',
#         'params': {'pipette': '96a1cafc-4536-482f-8eb9-8ebedba1f40b',
#          'labware': 'trash_yo',
#          'well': 'A1'}}]}]}},
#   'plates': {'post': {'plate_form': 'deep96',
#     'plate_name': 'FG_JCVISYN3-distro-0',
#     'plate_type': 'culture',
#     'status': 'planned',
#     'breadcrumb': None,
#     'uuid': '276126e0-1b46-4840-b5cb-e2b1e6a97739'}}},
#  {'data': {'wells': {'post': [{'address': 'A1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['9ed60323-c555-46a6-8fe0-5ac77ca60e62']},
#      {'address': 'B1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['92b51087-a215-4e8e-affd-43314ed7a92f']},
#      {'address': 'C1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['db63e835-6bff-4083-8b86-6c24200bee05']},
#      {'address': 'D1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['336dc562-8109-4a2b-8c4f-fd136dd1f565']},
#      {'address': 'E1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['78a28ab0-1c0e-4410-b598-4d2798d6e976']},
#      {'address': 'F1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['26f1805a-2d3d-45f5-b592-9e85e54a9918']},
#      {'address': 'G1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['170e83b3-b8a8-4493-9a95-34b66d8215fb']},
#      {'address': 'A2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['731750d5-93b4-4277-afa2-c70926183caf']},
#      {'address': 'B2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['61072769-f690-4c02-b02d-2e9018f62836']},
#      {'address': 'C2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['32bd8026-dc07-455d-854b-5a25b486921f']},
#      {'address': 'D2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['fb1f7b1c-0bf8-4305-bdd2-5a6f5adde93e']},
#      {'address': 'H1',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['10b216f0-3fa1-4c3a-ad63-ce7c72623980']},
#      {'address': 'E2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['bd6ed2ab-ac81-4d3b-95e9-0468997bc4b6']},
#      {'address': 'F2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': ['f5f9f712-57f6-4bec-a11c-d66eda3d3235']},
#      {'address': 'G2',
#       'media': 'lb',
#       'organism': 'E.coli Top10',
#       'volume': 1200,
#       'well_type': 'culture',
#       'plate_uuid': '44b416dd-1f94-4859-a757-d4d0edd4c636',
#       'samples': 