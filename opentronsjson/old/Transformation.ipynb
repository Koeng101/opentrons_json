# %%
from opentronsjson import plates,commands
import opentronsjson
import datetime
import uuid
import json
import itertools
from operator import itemgetter
with open('./../protocol-schema.json') as f:
    data = json.load(f)
from jsonschema import validate


with open('/home/koeng/Downloads/response_1554406909932.json') as f:
    test_plate = json.load(f)

opentrons = {'uuid': '43346aba-41e0-483d-ad43-d46a85a6ead5',
             'right_300': '9c3b3205-4fe3-4bf1-af3f-8cf9ab95d918',
             'left_10': '82e95a7a-f335-4178-a7b6-4f38954e497a'
            }
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
import string
class Plate():
    def __init__(self, height:int=8, length:int=12,locations:list=[]) -> None:
        positions = []
        for letter in list(string.ascii_uppercase[0:height]):
            for number in range(length):
                positions.append((letter, number+1))
        self.height = height
        self.length = length
        if locations==[]:
            self.locations = [x[0]+str(x[1]) for x in positions]
        else:
            self.locations = locations

    def rows(self)-> list:
        #tuples good strings bad
        return [list(g) for k, g in groupby(self.locations, key=lambda x: x[0])]
    def columns(self) -> list:
        # why not the same above, sed 's/x[0]/x[1:]'
        return [[x for x in self.locations if x[1:] == str(num+1)] for num in range(self.length)]
    def reverse_columns(self)-> list:
        return [sorted(x, reverse=True) for x in self.columns()]
    def flat_columns(self) -> list:
        # use a classmethod constructor
        # expose only public locations, wells (dict of dict of well), rows, columns
        return [item for sublist in self.columns() for item in sublist]


    def subcolumns(self)-> list:
        if self.height%2 != 0:
            raise StandardError('Not compatible with multichannel')
        spaces = int(self.height/8)
        subcolumns=[]
        for column in self.columns():
            for space in range(spaces):
                count = space
                subcolumn=[]
                while count < len(column):
                    subcolumn.append(column[count])
                    count+=spaces
                subcolumns.append(subcolumn)
        return subcolumns
    
    def use_wells(self,tips:list)-> str:
        self.locations = [v for i, v in enumerate(self.locations) if v not in tips]
        return tips

    def use_number(self,num_wells:int=8,columns=None) -> str:
        if columns == None:
            columns=self.reverse_columns()
        for column in columns:
            if len(column) >= num_wells:
                return self.use_wells(column[0:num_wells])
        raise ValueError("No more tips.")

    def derived_subcolumns(self,loc:list):
        return [[well if well in loc else None for well in col] for col in self.subcolumns()]

        
def data_transfer_comprehension(data_transfer, old_plate=Plate(),new_plate=Plate()):
    output=[]
    for transfer in data_transfer:
        original_index = old_plate.flat_columns().index(transfer[1])
        new_index = new_plate.flat_columns().index(transfer[2])
        for i in range(transfer[0]):
            old_well = old_plate.flat_columns()[i+original_index]
            new_well = new_plate.flat_columns()[i+new_index]
            output.append((old_well,new_well))
    return output
            

def efficient_transfer(derived:list,full=Plate().subcolumns()):
    derived = Plate(locations=derived).subcolumns()
    transfers=[]
    well = None
    for index,subcolumn in enumerate(derived):
        tip_count = 1
        loc_num=0
        wells=[]
        counter = 0
        for well_index,well in enumerate(subcolumn):

            # Check if this is a new well
            wells.append(well)

            # Check that this is not the last location we can pull from 
            if not well_index+2 > len(subcolumn):
                loc_num = full[index].index(subcolumn[well_index])-well_index-counter



            # If last location, add tips and location, reset new well
            if loc_num != 0:
                if loc_num != 50:
                    transfers.append((len(wells[:-1]),wells[:-1]))
                    wells=[wells[-1]]
                    tip_count=0
                    counter=loc_num
                else:
                    transfers.append((len(wells),wells))
                    wells=[]
                    tip_count=0
                    counter=loc_num
            
            loc_num=50
            tip_count+=1
    return transfers

# %%
def transfer(volume,from_wells,tipbox=Plate(),from_plate_layout=Plate(),to_plate_layout=Plate()):
    def efficient_tip(derived,full):
        transfers=[]
        well = None
        for index,subcolumn in enumerate(derived):
            tip_count = 1
            loc_num=0
            wells=[]
            for well_index,well in enumerate(subcolumn):

                # Check if this is a new well
                wells.append(well)

                # Check that this is not the last location we can pull from 
                if not well_index+2 > len(subcolumn):
                    loc_num = full[index].index(subcolumn[well_index+1])-well_index

                # If last location, add tips and location, reset new well
                if loc_num != 1:
                    transfers.append((tip_count,wells))
                    wells=[]
                    tip_count=0

                loc_num=0
                tip_count+=1
        return transfers
    
    transfers = efficient_tip(Plate(locations=from_wells).subcolumns(),from_plate_layout.subcolumns())
    to = []
    for step in transfers:
        tips = tipbox.use_number(step[0])
        to+=to_plate_layout.use_number(step[0],to_plate_layout.columns())
    transfer_from = [item for sublist in [step[1] for step in transfers] for item in sublist]
    
    individual_transfers = [(volume,) + transfer for transfer in list(zip(transfer_from,to))]
    return transfers,individual_transfers

# %%
class Protocol():
    def __init__(self,robot:dict,labware:dict,procedure:dict,protocol_schema:str='1.0.0',metadata:dict={},defaults:dict={},designer_application:dict={},pipettes:dict={}):
        # Metadata
        self.protocol_schema = protocol_schema
        self.metadata = metadata
        
        # Defaults
        if defaults == {}:
            self.defaults = opentronsjson.default_values
        else:
            self.defaults = defaults
        
        #Designer application
        if designer_application == {}:
            self.designer_application = opentronsjson.designer_application
        else:
            self.designer_application = designer_application
            
        # Pipettes 
        if pipettes == {}:
            self.pipettes = {
                robot['left_10']: opentronsjson.pipette("left", "p10_multi", "p10_multi_v1.3"),
                robot['right_300']: opentronsjson.pipette("right", "p300_multi", "p300_multi_v1.3")
            }
        else:
            self.pipettes = pipettes
        
        self.labware = labware
        self.procedure=procedure
            
    def toJSON(self):
         return {
             "protocol-schema": self.protocol_schema,
             "metadata": self.metadata,
             "default-values": self.defaults,
             "designer-application": self.designer_application,
             "robot": opentronsjson.ot2_standard,
             "pipettes": self.pipettes,
             "labware": self.labware,
             "procedure": self.procedure}
        
def plate_merge(robot,plate,breadcrumb=None,strain='E.coli Top10',transformant_volume=15,media='lb',transformation_volume=2):
    # Create new plate
    new_plate = {"plate_form": "96pcr",
                 "plate_name": "{}-transformation".format(plate['plate_name']),
                 "plate_type": "transformation",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": str(uuid.uuid4())}

    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(plate['uuid']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }

    # Addresses from
    addresses = []
    for well in plate['wells']:
        addresses.append(well['address'])

    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = robot['left_10']
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-10ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('5', '96-PCR-flat', name=new_plate['plate_name']),
        plate['uuid']: opentronsjson.labware('4', '96-PCR-flat', name=plate['plate_name'])
    }
    
    # Create new procedure
    procedure = []
    data_transfer = []
    high_level_transfers = efficient_transfer(addresses)
    volume = transformation_volume
    for transfer in high_level_transfers:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(transfer[0])[-1]))
        transfer_from = transfer[1][0]
        procedure.append(commands.aspirate(pipette,volume,plate['uuid'],transfer_from))
        transfer_to = new.use_number(transfer[0],columns=new.columns())[0]
        procedure.append(commands.dispense(pipette,volume,new_plate['uuid'],transfer_to))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))
        data_transfer.append((transfer[0],transfer_from,transfer_to))
    
    protocol = {'uuid': str(uuid.uuid4()),
               'description': metadata['protocolName'],
               'protocol': Protocol(robot,labware,[{'subprocedure': procedure}],metadata=metadata).toJSON(),
               'status': 'planned'}
    
    transfers = data_transfer_comprehension(data_transfer)
    new_wells=[]
    for transfer in transfers:
        old_well = {}
        for well in plate['wells']:
            if well['address'] == transfer[0]:
                old_well = well
        new_well = {'address': transfer[1],
                    'media': media,
                    'organism': strain,
                    'plate_uuid': new_plate['uuid'],
                    'quantity': None,
                    'samples': [sample['uuid'] for sample in old_well['samples']],
                    'volume': transformant_volume+transformation_volume,
                   'well_type': 'transformation'}
        new_wells.append(new_well)
    
    output = {'Plate': [new_plate],
             'Well': new_wells,
             'Protocol': [protocol]}
    return output
    
        

result = transformation(opentrons,test_plate)#['protocol']
#validate(result,schema=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-122c5c754c54> in <module>
#     119
#     120
# --> 121 result = transformation(opentrons,test_plate)#['protocol']
#     122 #validate(result,schema=data)
#
# NameError: name 'transformation' is not defined

# %%
import requests
r = requests.get('https://api.freegenes.org/plates/recurse/dcf981a7-683c-4bad-acfe-8ed35217ec36').json()

# %%
def plates_join_parts(parts:list,plates:list,status=None): 
    """Can merge maximum 6 plates into 1. Parts are expressed as UUIDs. Plates are plate recursions """
    used_parts = []
    plate_dict = {}
    # for plate in plates
    #     for part in parts:
    #          if part in plate"
    #              used
    for plate in plates:
        target_wells = []
        for well in plate['wells']:
            for sample in well['samples']:
                part_uuid = sample['part']['uuid']
                if part_uuid in parts and part_uuid not in used_parts:
                    #if sample['status'] == 'Confirmed':
                    if sample['status'] == None:
                        target_wells.append(well['address'])
                        used_parts.append(part_uuid)
        plate_dict[plate['uuid']] = target_wells
    return plate_dict

def group_locs(locs,plate=Plate()):
    # this is good with iter
    # sad without
    transfers = []
    for col in plate.derived_subcolumns(locs):
        trans = []
        for i,well in enumerate(col):
            if well != None:
                trans.append(well)

            if i+1 == len(col):
                if trans != []: transfers.append(trans)
            else:
                if col[i+1] == None:
                    if trans != []: transfers.append(trans)
                    trans = []
    return transfers

def high_level_transfer(parts:list,plates:list,status=None):
    plate_dict = plates_join_parts(parts,plates,status)
    return {k: group_locs(v) for k,v in plate_dict.items()}

def plate_merge(name:str,plate_uuid:str,plate_num:int,plate_dict:dict,robot:dict,breadcrumb:None):
    new_plate = {"plate_form": "standard96",
                 "plate_name": "{}-distro-{}".format(name,str(plate_num)),
                 "plate_type": "distribution_glycerol_stock",
                 "status": "planned",
                 "breadcrumb": breadcrumb,
                 "uuid": plate_uuid}
    # Metadata
    metadata = {
            "protocolName": "Plate merge to create {}".format(new_plate['plate_name']),
            "author": "Keoni Gandall",
            "datetime": "{}".format(str(datetime.datetime.now()))
          }


    # Tipbox
    tipbox = Plate()
    new = Plate()

    # Labware
    pipette = str(uuid.uuid4())
    tips = '11_tip_box'

    labware = {
        tips: opentronsjson.labware('11',"opentrons-tiprack-300ul",name="11_tip_box"),
        'trash_yo': opentronsjson.labware('12',"fixed-trash",name="Trash yo"),
        new_plate['uuid']: opentronsjson.labware('10', '96-deep-well', name=new_plate['plate_name']),
    }
    for i,k in enumerate(list(set([d['from'] for d in plate_dict]))):
        labware[k] = opentronsjson.labware(str(i+4), '96-flat', name=k)
    

    procedure = []
    vol=7
    
    to_wells = []
    from_wells = []
    for d in plate_dict:
        procedure.append(commands.pick_up_tip(pipette,tips,tipbox.use_number(len(d['trans']))[-1]))
        procedure.append(commands.aspirate(pipette,vol,d['from'],d['trans'][0]))
        from_wells.append((d['from'],d['trans']))
        to_wells.append((d['to'],new.use_number(len(d['trans']),columns=new.subcolumns())))
        procedure.append(commands.dispense(pipette,vol,d['to'], to_wells[-1][1][-1]))
        procedure.append(commands.drop_tip(pipette,'trash_yo','A1'))

    for from_well,to_well in zip(from_wells,to_wells):
        print(from_wells, to_wells)
        for f_w,t_w in zip(from_well[1],to_well[1]):
            #print(f_w)
            #print(t_w)
            pass
        
    protocol = Protocol({},labware,[{'subprocedure': procedure}],metadata=metadata,pipettes={pipette:opentronsjson.pipette("left", "p50_multi", "p50_multi_v1.3")}).toJSON()
    
    
    return protocol

def compile_parts(collection_name:str,parts:list,plates:list,status='Confirmed'):
    groups = high_level_transfer(parts,plates,status)
    num_parts = sum([sum([len(tran) for tran in v])for k,v in groups.items()])
    plate_num = int(num_parts/96) + 1

    # Gen protocol
    new_plate = str(uuid.uuid4())
    protocol = []
    count = 0
    for k,v in groups.items():
        for trans in v:
            if count+len(trans)>96: 
                print('new')
                new_plate = str(uuid.uuid4())
                count=0
            else:
                protocol.append({'from': k, 'to': new_plate, 'trans':trans})
                count+=len(trans)
    compile_protocol = {key:[x for x in value if key != 'to' ] for key, value in itertools.groupby(sorted(protocol, key=itemgetter('to')), key=itemgetter('to'))}
    return [plate_merge(collection_name,k,i,v,{},None) for i, (k, v) in enumerate(compile_protocol.items())]
        
        
                        
compiled = compile_parts('FG_JCVISYN3',['9d0aeaa7-6ed5-4110-9759-4c6a0340acef','9198f7b6-3edd-4f7f-a52d-6c8ef0ac2044','4f425ab9-dc81-4e17-a9f6-52f10fcc000f','cbcfd9ae-7348-4448-9191-9c242e915f23','c8bc192b-557e-45b5-8831-a8292c8b6176'], [r])
# Out:
# [('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E7'])] [('7855f827-295a-4e8f-906d-788d38a3c5ac', ['A1'])]

# %%
plates = requests.get('https://api.freegenes.org/plates/').json()
plate_list = []
for plate in plates:
    if plate['plate_name'][-1] != 'a':
        plate_list.append(requests.get('https://api.freegenes.org/plates/recurse/{}'.format(plate['uuid'])).json())
parts = [x['uuid'] for x in requests.get('https://api.freegenes.org/collections/recurse/78c1a296-69ff-4e42-a2a8-9915bc84bd71').json()['parts']]

# %%
compiled = compile_parts('FG_JCVISYN3',parts,plate_list)
# Out:
# new
# new
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# [('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H7']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['F9']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E10']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G11']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['E12', 'F12']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H12']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['B1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['D1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G1', 'H1']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A2', 'B2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E2', 'F2', 'G2']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C3', 'D3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G3', 'H3']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G4', 'H4']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A5', 'B5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['E5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G5']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G6']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['A7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['C7', 'D7', 'E7']), ('66c4c1bc-6259-4036-a510-3ecdbeb40cf2', ['G7', 'H7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C1', 'D1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F1']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A2']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E3']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E4']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D5', 'E5', 'F5', 'G5']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A6', 'B6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['F6']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E7', 'F7']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['D8']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['C9', 'D9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['H9']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['G10']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['B11']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['A12', 'B12']), ('1f9db7dc-92d9-4201-a5df-f999ac2c2d2f', ['E12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['F2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['H2']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['D3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['G3']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['A12', 'B12', 'C12']), ('fcc9165e-bd34-4aa9-8967-6591fbc0d0da', ['E12', 'F12']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C2', 'D2']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['G6', 'H6']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['C7']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['E7'])] [('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['D1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['E1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['F1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['G1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['H1']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['A2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['B2']), ('22da7db7-8d19-433e-826c-d7dcdfee4a26', ['C2', 'D2']), ('22da7db7-8d19-433e-826c-d7dc ...
# ...
# [('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A1', 'B1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F1', 'G1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A2']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F2']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D3', 'E3']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E4', 'F4']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D5', 'E5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['G5', 'H5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D6']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F6']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A7']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D7', 'E7', 'F7']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['G8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['H9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E10', 'F10', 'G10', 'H10']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B11', 'C11']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A12']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C1', 'D1']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H1']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A2']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G2']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C4', 'D4', 'E4']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['F5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A6']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G6']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['B7']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G7']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E8']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G8', 'H8']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['D9']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G9', 'H9']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['D10']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H10']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C11']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E11']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G12']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['C1', 'D1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['F1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['H1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['A2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['H2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D3']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D4', 'E4', 'F4', 'G4']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['A5']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['F6', 'G6', 'H6']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B1', 'C1', 'D1', 'E1']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H1']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B2']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['D3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H5']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C6'])] [('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['A1', 'B1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['C1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['D1', 'E1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['F1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['G1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['A2', 'B2']), ('57dd01 ...
# [('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A1', 'B1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F1', 'G1']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A2']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F2']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D3', 'E3']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E4', 'F4']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D5', 'E5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['G5', 'H5']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D6']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F6']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A7']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D7', 'E7', 'F7']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['G8']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['F9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['H9']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['E10', 'F10', 'G10', 'H10']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['B11', 'C11']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['A12']), ('dcf981a7-683c-4bad-acfe-8ed35217ec36', ['D12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C1', 'D1']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H1']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A2']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G2']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C4', 'D4', 'E4']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['F5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H5']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A6']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G6']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['B7']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G7']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E8']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G8', 'H8']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['D9']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G9', 'H9']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['D10']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['H10']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C11']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E11']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['A12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['C12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['E12']), ('fafd13fe-33a6-4d0e-89d6-070f901dbf37', ['G12']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['C1', 'D1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['F1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['H1']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['A2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['H2']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D3']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['D4', 'E4', 'F4', 'G4']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['A5']), ('f74a8ac1-69b1-4100-b784-3eafbd8682ab', ['F6', 'G6', 'H6']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B1', 'C1', 'D1', 'E1']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H1']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['B2']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['D3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['G3']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['A4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H4']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['H5']), ('a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e', ['C6'])] [('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['A1', 'B1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['C1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['D1', 'E1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['F1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['G1']), ('57dd013b-9eeb-4d07-8e96-c8e234a33339', ['A2', 'B2']), ('57dd01 ...
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]
# [('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H8']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['B9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['D9', 'E9', 'F9', 'G9']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['F10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['H10']), ('af2866f7-7a89-45d7-ae5a-0b2c2d0829d7', ['A11', 'B11', 'C11', 'D11', 'E11', 'F11'])] [('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['C1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['D1', 'E1', 'F1', 'G1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['H1']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['A2']), ('f71dd38d-7a79-4592-a467-73d2ecce08a5', ['B2', 'C2', 'D2', 'E2', 'F2', 'G2'])]

# %%
with open('/home/koeng/Downloads/jcvisyn3_distro_0.json', 'w') as outfile:  
    json.dump(compiled[0], outfile)

# %%
def transfer_wells(from_plate:dict,to_plate:str,from_address:str,to_address:str,from_vol:int,total_to_vol:int):
    obj = {'wells': {'post': [], 'put': []}, 'samples': {'post': [], 'put': []}}
    for well in from_plate['wells']:
        if well['address'] == from_address:
            obj['wells']['put'].append({'uuid': well['uuid'],'volume': well['volume']-from_vol})
            obj['wells']['post'].append({'organism': well['organism'], 'plate_uuid': to_plate, 'media': 'lb', 'volume': total_to_vol, 'well_type': 'culture'})
            obj['samples']['post'].append({''})

# %%
from jsonschema import validate
import json
with open('/home/koeng/notebooks/validation/protocolSchemaV3.json') as json_file:  
    schema = json.load(json_file)

validate(instance=compiled[0], schema=schema)

# %%
compiled[0]
# Out:
# {'protocol-schema': '1.0.0',
#  'metadata': {'protocolName': 'Plate merge to create FG_JCVISYN3-distro-0',
#   'author': 'Keoni Gandall',
#   'datetime': '2019-05-21 10:42:56.768090'},
#  'default-values': {'aspirate-flow-rate': {'p10_single': 5,
#    'p10_multi': 5,
#    'p50_single': 25,
#    'p50_multi': 25,
#    'p300_single': 150,
#    'p300_multi': 150,
#    'p1000_single': 500},
#   'dispense-flow-rate': {'p10_single': 10,
#    'p10_multi': 10,
#    'p50_single': 50,
#    'p50_multi': 50,
#    'p300_single': 300,
#    'p300_multi': 300,
#    'p1000_single': 1000},
#   'aspirate-mm-from-bottom': 1,
#   'dispense-mm-from-bottom': 0.5,
#   'touch-tip-mm-from-top': -1},
#  'designer-application': {'application-name': 'opentrons_json',
#   'application-version': '1.0.0',
#   'data': {}},
#  'robot': {'model': 'OT-2 Standard'},
#  'pipettes': {'1e504449-a1cf-44dd-8d09-ee266e5e5207': {'type': 'pipette',
#    'mount': 'left',
#    'name': 'p50_multi',
#    'model': 'p50_multi_v1.3'}},
#  'labware': {'11_tip_box': {'slot': '11',
#    'model': 'opentrons-tiprack-300ul',
#    'name': '11_tip_box'},
#   'trash_yo': {'slot': '12', 'model': 'fixed-trash', 'name': 'Trash yo'},
#   '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa': {'slot': '10',
#    'model': '96-deep-well',
#    'name': 'FG_JCVISYN3-distro-0'},
#   'f74a8ac1-69b1-4100-b784-3eafbd8682ab': {'slot': '4',
#    'model': '96-flat',
#    'name': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab'},
#   'dcf981a7-683c-4bad-acfe-8ed35217ec36': {'slot': '5',
#    'model': '96-flat',
#    'name': 'dcf981a7-683c-4bad-acfe-8ed35217ec36'},
#   'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e': {'slot': '6',
#    'model': '96-flat',
#    'name': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e'},
#   'fafd13fe-33a6-4d0e-89d6-070f901dbf37': {'slot': '7',
#    'model': '96-flat',
#    'name': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37'}},
#  'procedure': [{'subprocedure': [{'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'A1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'F1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'A2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'F2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G2'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D3'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B2'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E2'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'E4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D2'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A1'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'B5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H1'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C2'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F2'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A2'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'G5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H2'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'F6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'A7'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D7'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'B8'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A3'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'E8'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H3'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H4'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'G8'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A4'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G4'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'A9'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B4'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F4'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'F9'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C4'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E4'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'H9'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D4'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A4'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'E10'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H4'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'B11'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'A12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'dcf981a7-683c-4bad-acfe-8ed35217ec36',
#       'well': 'D12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'C1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'H1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A5'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'A2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H5'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'C4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'A5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'C5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'F5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A6'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'H5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H6'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'A6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'B7'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G7'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'E8'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G8'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A7'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'D9'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H7'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G9'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'D10'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'H10'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'C11'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'E11'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'A12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A8'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'C12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H8'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'E12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'fafd13fe-33a6-4d0e-89d6-070f901dbf37',
#       'well': 'G12'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'C1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'F1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'H1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'A2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A9'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'D2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H9'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H10'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'H2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A10'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G10'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'D3'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B10'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C10'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'D4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F10'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B10'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'A5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G10'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F11'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'f74a8ac1-69b1-4100-b784-3eafbd8682ab',
#       'well': 'F6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C11'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B11'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'B1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G11'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A10'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'H1'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H10'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A11'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'B2'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H11'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'H12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'A3'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'A12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'G12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'D3'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'B12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'F12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'G3'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'C12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'E12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'A4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'D12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'D12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'C4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'E12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'C12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'H4'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'F12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'B12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'H5'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'G12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}},
#     {'command': 'pick-up-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': '11_tip_box',
#       'well': 'A12'}},
#     {'command': 'aspirate',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': 'a5b63ac0-bdcf-4dc2-91aa-c9e5cda6086e',
#       'well': 'C6'}},
#     {'command': 'dispense',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'volume': 7,
#       'labware': '0b13e95b-bcf4-4a35-a2c3-545fd1b4bafa',
#       'well': 'H12'}},
#     {'command': 'drop-tip',
#      'params': {'pipette': '1e504449-a1cf-44dd-8d09-ee266e5e5207',
#       'labware': 'trash_yo',
#       'well': 'A1'}}]}]}
