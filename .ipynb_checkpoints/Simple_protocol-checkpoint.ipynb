# %%
import opentrons_json as oj
from opentrons_json import plates,commands
import uuid
from jsonschema import validate
import json
with open('opentrons_json/protocol-schema.json') as f:
    data = json.load(f)

# %%
pipette = str(uuid.uuid4())
tip_box = str(uuid.uuid4())
plate_1 = str(uuid.uuid4())
plate_2 = str(uuid.uuid4())
protocol = {
    "protocol-schema": "1.0.0",

  "metadata": {
    "protocol-name": "Example transfer protocol",
    "author": "Keoni",
    "description": "An example of json .",
    "created": 1519916981999,
    "last-modified": 1519917009476,
    "category": "basic pipetting",
    "subcategory": "sample prep",
    "tags": ["simple", "example"]
  },
    "default-values": oj.default_values,
    "designer-application": oj.designer_application,
    "robot": oj.ot2_standard,
    "pipettes": {pipette:oj.pipette("left", "p300_single", "p300_single_v1.3")},
    "labware": {
        tip_box: oj.labware('1',"GEB-tiprack-300uL"),
        plate_1: oj.labware('2',"96-flat"),
        plate_2: oj.labware('3',"96-flat")
    },
    "procedure": [
        {"subprocedure": [
        oj.commands.aspirate(pipette,50,plate_1,'A1'),
        oj.commands.dispense(pipette,50,plate_2,'A2')]}]
}

# %%
validate(instance=protocol,schema=data)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-18-bd10945b6eb0> in <module>
# ----> 1 validate(instance=protocol,schema=data)
#
# /usr/lib/python3.7/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     539         cls = validator_for(schema)
#     540     cls.check_schema(schema)
# --> 541     cls(schema, *args, **kwargs).validate(instance)
#
# /usr/lib/python3.7/site-packages/jsonschema/validators.py in validate(self, *args, **kwargs)
#     128         def validate(self, *args, **kwargs):
#     129             for error in self.iter_errors(*args, **kwargs):
# --> 130                 raise error
#     131
#     132         def is_type(self, instance, type):
#
# ...

# %%
protocol_test = {
    "protocol-schema": "1.0.0",
    "metadata": {
        "protocol-name": "asdf",
        "author": "",
        "description": "",
        "created": 1551797331781,
        "last-modified": None,
        "category": None,
        "subcategory": None,
        "tags": []
    },
    "designer-application": {
        "application-name": "opentrons/protocol-designer",
        "application-version": "1.0.0",
        "data": {
            "pipetteTiprackAssignments": {
                "pipette:p10_single_v1.3:cabe9b10-3f55-11e9-9a56-9f48962d7175": "tiprack-10ul",
                "pipette:p10_multi_v1.3:cabe9b11-3f55-11e9-9a56-9f48962d7175": "tiprack-10ul"
            },
            "dismissedWarnings": {
                "form": {},
                "timeline": {}
            },
            "ingredients": {},
            "ingredLocations": {},
            "savedStepForms": {},
            "orderedSteps": []
        }
    },
    "robot": {
        "model": "OT-2 Standard"
    },
    "pipettes": {
        "pipette:p10_single_v1.3:cabe9b10-3f55-11e9-9a56-9f48962d7175": {
            "mount": "left",
            "model": "p10_single_v1"
        },
        "pipette:p10_multi_v1.3:cabe9b11-3f55-11e9-9a56-9f48962d7175": {
            "mount": "right",
            "model": "p10_multi_v1"
        }
    },
    "labware": {
        "trashId": {
            "slot": "12",
            "display-name": "Trash",
            "model": "fixed-trash"
        }
    },
    "procedure": [
        {
            "annotation": {
                "name": "TODO Name 0",
                "description": "todo description"
            },
            "subprocedure": []
        }
    ]
}
validate(instance=protocol_test,schema=data)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-10-cf598cb282a3> in <module>
#      59     ]
#      60 }
# ---> 61 validate(instance=protocol_test,schema=data)
#
# /usr/lib/python3.7/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     539         cls = validator_for(schema)
#     540     cls.check_schema(schema)
# --> 541     cls(schema, *args, **kwargs).validate(instance)
#
# /usr/lib/python3.7/site-packages/jsonschema/validators.py in validate(self, *args, **kwargs)
#     128         def validate(self, *args, **kwargs):
#     129             for error in self.iter_errors(*args, **kwargs):
# --> 130                 raise error
#     131
#     132         def is_type(self, instance, type):
#
# ValidationError: 'default-values' is a required property
#
# Failed validating 'required' in schema:
# ...
